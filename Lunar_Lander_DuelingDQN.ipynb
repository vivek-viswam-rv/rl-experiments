# %% [markdown]
# # Lunar Lander - Dueling DQN

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Agent-related Class Definitions

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DuelingDQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DuelingDQN, self).__init__()
        self.feature = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )

        # Value stream
        self.value_stream = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Advantage stream
        self.advantage_stream = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )

    def forward(self, x):
        x = self.feature(x)
        value = self.value_stream(x)
        advantage = self.advantage_stream(x)
        # Combine value and advantage into Q-values
        q_vals = value + (advantage - advantage.mean(dim=1, keepdim=True))
        return q_vals


class DQNAgent:
    BATCH_SIZE = 32
    EPSILON_START = 1
    EPSILON_CUTOFF = 0.05
    EPSILON_DECAY = 100000
    GAMMA = 0.99
    LR = 1e-4
    MEMORY_SIZE = 10000
    total_steps = 0

    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = ReplayBuffer(self.MEMORY_SIZE)
        self.steps_done = 0
        self.epsilon = self.EPSILON_START

    def select_e_greedy_action(self, env, state):
        if random.random() < self.epsilon:
            return random.randint(0, env.action_space.n - 1)
        else:
            state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state).argmax(dim=1).item()

    def select_greedy_action(self, state):
      state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
      with torch.no_grad():
          return self.policy_net(state).argmax(dim=1).item()

    def decay_epsilon(self):
      self.total_steps += 1
      self.epsilon = max(self.EPSILON_CUTOFF, self.EPSILON_START - (self.total_steps / self.EPSILON_DECAY))

    def train(self):
        if len(self.memory) < self.BATCH_SIZE:
            return
        batch = self.memory.sample(self.BATCH_SIZE)

        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(np.array(actions), dtype=torch.int64, device=self.device).unsqueeze(1)
        rewards = torch.tensor(np.array(rewards), dtype=torch.float32, device=self.device).unsqueeze(1)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=self.device)
        dones = torch.tensor(np.array(dones), dtype=torch.float32, device=self.device).unsqueeze(1)
        current_q = self.policy_net(states).gather(1, actions)
        next_q = self.target_net(next_states).max(1, keepdim=True)[0].detach()
        target_q = rewards + (self.GAMMA * next_q * (1 - dones))

        loss = F.mse_loss(target_q, current_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

class DuelingDQNAgent(DQNAgent):
    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DuelingDQN(state_dim, action_dim).to(self.device)
        self.target_net = DuelingDQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = ReplayBuffer(self.MEMORY_SIZE)
        self.steps_done = 0
        self.epsilon = self.EPSILON_START

# %% [markdown]
# ## Training Function Definition

# %%
def train_q_values_ddqn(env, env_name,target_update_interval = 10, training_episodes = 1000, agent_class = DuelingDQNAgent):
  MAX_STEPS = 1000
  CONVERGENCE_REWARD_COUNT = 20
  CONVERGENCE_MIN_REWARD = 270

  state_dim = env.observation_space.shape[0]
  action_dim = env.action_space.n
  agent = agent_class(state_dim, action_dim)
  rewards_per_episode = []
  episode_times = []
  steps_per_episode = []
  epsilon_values = []

  for episode in range(training_episodes):
    start_time = time.time()
    obs, _ = env.reset()
    state = obs
    total_reward = 0
    done = False
    steps_taken = 0
    episode_transitions = []

    epsilon_values.append(agent.epsilon)

    while not done and steps_taken < MAX_STEPS:
        action = agent.select_e_greedy_action(env, state)
        obs, reward, done, _, _ = env.step(action)
        next_state = np.array(obs, dtype=np.float32)
        episode_transitions.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        steps_taken += 1

        agent.decay_epsilon()

    average_rewards_over_last_episodes = np.mean(rewards_per_episode[-CONVERGENCE_REWARD_COUNT:])
    
    if average_rewards_over_last_episodes >= CONVERGENCE_MIN_REWARD and total_reward >= CONVERGENCE_MIN_REWARD:
        print("Early stopping condition met! Stopping training.")
        print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        break
    
    for transition in episode_transitions:
        agent.memory.push(*transition)
        agent.update_target_network()

    for _ in range(len(episode_transitions)):
        agent.train()

    end_time = time.time()
    episode_time = end_time - start_time
    episode_times.append(episode_time)
    rewards_per_episode.append(total_reward)
    steps_per_episode.append(steps_taken)

    if episode % 10 == 0:
      print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")

    if episode % 100 == 0:
      checkpoint = {
        'policy_net_state_dict': agent.policy_net.state_dict(),
        'optimizer_state_dict': agent.optimizer.state_dict(),
        'total_steps': agent.total_steps,
        'rewards_per_episode': rewards_per_episode,
        'epsilon_values': epsilon_values,
        'episode_times': episode_times,
        'steps_per_episode': steps_per_episode
      }

      torch.save(checkpoint, "dueling_dqn_lunar_lander_v3_checkpoint.pth")
      torch.save(agent.policy_net.state_dict(), "dueling_ddqn_lunar_lander_v3.pth")
      print("Checkpoint Reached!")

  return agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode

# %% [markdown]
# ## LunarLander-v3 - Training

# %%
env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

trained_agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode = train_q_values_ddqn(lunar_env, env_name, training_episodes = 2000)

checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'total_steps': trained_agent.total_steps,
    'rewards_per_episode': rewards_per_episode,
    'epsilon_values': epsilon_values,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}

torch.save(checkpoint, "dueling_dqn_lunar_lander_v3_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "dueling_ddqn_lunar_lander_v3.pth")
# Out:
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 1: Total Reward: -51.735, Epsilon: 0.999, Steps: 79, Time: 0.43s
# Checkpoint Reached!
# Episode 11: Total Reward: -126.359, Epsilon: 0.989, Steps: 87, Time: 0.53s
# Episode 21: Total Reward: -225.225, Epsilon: 0.980, Steps: 116, Time: 0.81s
# Episode 31: Total Reward: -110.901, Epsilon: 0.971, Steps: 68, Time: 0.49s
# Episode 41: Total Reward: -367.644, Epsilon: 0.962, Steps: 116, Time: 0.75s
# Episode 51: Total Reward: -92.019, Epsilon: 0.952, Steps: 63, Time: 0.40s
# Episode 61: Total Reward: -97.824, Epsilon: 0.942, Steps: 94, Time: 0.56s
# Episode 71: Total Reward: -237.737, Epsilon: 0.933, Steps: 81, Time: 0.50s
# Episode 81: Total Reward: -254.594, Epsilon: 0.924, Steps: 103, Time: 0.70s
# Episode 91: Total Reward: -149.903, Epsilon: 0.915, Steps: 82, Time: 0.53s
# Episode 101: Total Reward: -101.253, Epsilon: 0.905, Steps: 87, Time: 0.53s
# Checkpoint Reached!
# Episode 111: Total Reward: -82.232, Epsilon: 0.896, Steps: 96, Time: 0.61s
# Episode 121: Total Reward: -91.047, Epsilon: 0.887, Steps: 89, Time: 0.54s
# Episode 131: Total Reward: -153.004, Epsilon: 0.877, Steps: 81, Time: 0.48s
# Episode 141: Total Reward: -89.563, Epsilon: 0.867, Steps: 113, Time: 0.71s
# Episode 151: Total Reward: -108.977, Epsilon: 0.857, Steps: 139, Time: 0.87s
# Episode 161: Total Reward: -90.668, Epsilon: 0.848, Steps: 77, Time: 0.44s
# Episode 171: Total Reward: -185.197, Epsilon: 0.837, Steps: 113, Time: 0.72s
# Episode 181: Total Reward: -66.735, Epsilon: 0.827, Steps: 69, Time: 0.44s
# Episode 191: Total Reward: -85.210, Epsilon: 0.815, Steps: 87, Time: 0.54s
# Episode 201: Total Reward: -96.892, Epsilon: 0.806, Steps: 90, Time: 0.54s
# Checkpoint Reached!
# Episode 211: Total Reward: -157.530, Epsilon: 0.796, Steps: 121, Time: 0.70s
# Episode 221: Total Reward: -115.870, Epsilon: 0.785, Steps: 117, Time: 0.70s
# Episode 231: Total Reward: -205.095, Epsilon: 0.777, Steps: 79, Time: 0.52s
# Episode 241: Total Reward: -55.498, Epsilon: 0.767, Steps: 92, Time: 0.55s
# Episode 251: Total Reward: -85.448, Epsilon: 0.757, Steps: 98, Time: 0.63s
# Episode 261: Total Reward: -61.748, Epsilon: 0.747, Steps: 89, Time: 0.55s
# Episode 271: Total Reward: -124.822, Epsilon: 0.737, Steps: 107, Time: 0.64s
# Episode 281: Total Reward: -51.094, Epsilon: 0.725, Steps: 115, Time: 0.73s
# Episode 291: Total Reward: -81.343, Epsilon: 0.714, Steps: 136, Time: 0.77s
# Episode 301: Total Reward: -37.479, Epsilon: 0.702, Steps: 127, Time: 0.72s
# Checkpoint Reached!
# Episode 311: Total Reward: -6.969, Epsilon: 0.691, Steps: 123, Time: 0.77s
# Episode 321: Total Reward: -53.002, Epsilon: 0.679, Steps: 105, Time: 0.59s
# Episode 331: Total Reward: -66.333, Epsilon: 0.667, Steps: 73, Time: 0.43s
# Episode 341: Total Reward: -85.609, Epsilon: 0.654, Steps: 78, Time: 0.48s
# Episode 351: Total Reward: -67.124, Epsilon: 0.643, Steps: 138, Time: 0.85s
# Episode 361: Total Reward: 16.707, Epsilon: 0.630, Steps: 113, Time: 0.72s
# Episode 371: Total Reward: -136.745, Epsilon: 0.618, Steps: 156, Time: 0.89s
# Episode 381: Total Reward: -24.139, Epsilon: 0.607, Steps: 87, Time: 0.54s
# Episode 391: Total Reward: -253.604, Epsilon: 0.596, Steps: 132, Time: 0.82s
# Episode 401: Total Reward: 12.506, Epsilon: 0.582, Steps: 133, Time: 0.80s
# Checkpoint Reached!
# Episode 411: Total Reward: -61.978, Epsilon: 0.567, Steps: 76, Time: 0.44s
# Episode 421: Total Reward: -65.707, Epsilon: 0.554, Steps: 73, Time: 0.42s
# Episode 431: Total Reward: 2.729, Epsilon: 0.514, Steps: 103, Time: 0.68s
# Episode 441: Total Reward: -16.618, Epsilon: 0.492, Steps: 196, Time: 1.11s
# Episode 451: Total Reward: 13.385, Epsilon: 0.459, Steps: 1000, Time: 5.72s
# Episode 461: Total Reward: -15.226, Epsilon: 0.426, Steps: 115, Time: 0.57s
# Episode 471: Total Reward: 13.808, Epsilon: 0.358, Steps: 1000, Time: 4.53s
# Episode 481: Total Reward: -9.436, Epsilon: 0.288, Steps: 120, Time: 0.58s
# Episode 491: Total Reward: -91.562, Epsilon: 0.189, Steps: 880, Time: 4.08s
# Episode 501: Total Reward: -2.937, Epsilon: 0.099, Steps: 1000, Time: 4.58s
# Checkpoint Reached!
# Episode 511: Total Reward: -40.668, Epsilon: 0.050, Steps: 1000, Time: 4.58s
# Episode 521: Total Reward: -116.545, Epsilon: 0.050, Steps: 1000, Time: 4.67s
# Episode 531: Total Reward: -85.232, Epsilon: 0.050, Steps: 1000, Time: 4.91s
# Episode 541: Total Reward: 135.525, Epsilon: 0.050, Steps: 971, Time: 5.63s
# Episode 551: Total Reward: 100.400, Epsilon: 0.050, Steps: 733, Time: 4.15s
# Episode 561: Total Reward: -15.266, Epsilon: 0.050, Steps: 173, Time: 1.09s
# Episode 571: Total Reward: 303.466, Epsilon: 0.050, Steps: 271, Time: 1.96s
# Episode 581: Total Reward: 273.689, Epsilon: 0.050, Steps: 284, Time: 1.95s
# Episode 591: Total Reward: 1.543, Epsilon: 0.050, Steps: 213, Time: 1.43s
# Episode 601: Total Reward: -79.695, Epsilon: 0.050, Steps: 426, Time: 2.82s
# Checkpoint Reached!
# Episode 611: Total Reward: -277.872, Epsilon: 0.050, Steps: 961, Time: 6.39s
# Episode 621: Total Reward: -86.892, Epsilon: 0.050, Steps: 124, Time: 0.85s
# Episode 631: Total Reward: 23.597, Epsilon: 0.050, Steps: 1000, Time: 6.77s
# Episode 641: Total Reward: -152.105, Epsilon: 0.050, Steps: 813, Time: 5.55s
# Episode 651: Total Reward: -230.885, Epsilon: 0.050, Steps: 818, Time: 5.43s
# Episode 661: Total Reward: -63.553, Epsilon: 0.050, Steps: 1000, Time: 6.92s
# Episode 671: Total Reward: -17.275, Epsilon: 0.050, Steps: 113, Time: 0.63s
# Episode 681: Total Reward: -21.171, Epsilon: 0.050, Steps: 114, Time: 0.60s
# Episode 691: Total Reward: 201.211, Epsilon: 0.050, Steps: 443, Time: 2.18s
# Episode 701: Total Reward: 208.676, Epsilon: 0.050, Steps: 345, Time: 1.70s
# Checkpoint Reached!
# Episode 711: Total Reward: 257.736, Epsilon: 0.050, Steps: 423, Time: 2.03s
# Episode 721: Total Reward: 254.554, Epsilon: 0.050, Steps: 367, Time: 1.90s
# Episode 731: Total Reward: 237.018, Epsilon: 0.050, Steps: 197, Time: 1.06s
# Episode 741: Total Reward: 178.028, Epsilon: 0.050, Steps: 354, Time: 1.74s
# Episode 751: Total Reward: -47.880, Epsilon: 0.050, Steps: 171, Time: 0.80s
# Episode 761: Total Reward: 247.629, Epsilon: 0.050, Steps: 307, Time: 1.67s
# Episode 771: Total Reward: 234.250, Epsilon: 0.050, Steps: 273, Time: 1.33s
# Episode 781: Total Reward: 244.777, Epsilon: 0.050, Steps: 596, Time: 3.06s
# Episode 791: Total Reward: 50.390, Epsilon: 0.050, Steps: 94, Time: 0.48s
# Episode 801: Total Reward: 234.179, Epsilon: 0.050, Steps: 292, Time: 1.41s
# Checkpoint Reached!
# Episode 811: Total Reward: -5.371, Epsilon: 0.050, Steps: 1000, Time: 5.00s
# Episode 821: Total Reward: 220.026, Epsilon: 0.050, Steps: 275, Time: 1.38s
# Episode 831: Total Reward: 256.674, Epsilon: 0.050, Steps: 726, Time: 3.56s
# Episode 841: Total Reward: -45.475, Epsilon: 0.050, Steps: 1000, Time: 5.03s
# Episode 851: Total Reward: 223.765, Epsilon: 0.050, Steps: 485, Time: 2.57s
# Episode 861: Total Reward: 198.438, Epsilon: 0.050, Steps: 413, Time: 2.10s
# Episode 871: Total Reward: 190.599, Epsilon: 0.050, Steps: 334, Time: 1.73s
# Episode 881: Total Reward: 241.933, Epsilon: 0.050, Steps: 352, Time: 1.97s
# Episode 891: Total Reward: 194.393, Epsilon: 0.050, Steps: 443, Time: 2.33s
# Episode 901: Total Reward: 221.657, Epsilon: 0.050, Steps: 554, Time: 2.63s
# Checkpoint Reached!
# Episode 911: Total Reward: 273.856, Epsilon: 0.050, Steps: 513, Time: 2.51s
# Episode 921: Total Reward: 124.530, Epsilon: 0.050, Steps: 1000, Time: 4.91s
# Episode 931: Total Reward: 263.197, Epsilon: 0.050, Steps: 297, Time: 1.59s
# Episode 941: Total Reward: 234.645, Epsilon: 0.050, Steps: 381, Time: 1.95s
# Episode 951: Total Reward: 269.913, Epsilon: 0.050, Steps: 301, Time: 1.51s
# Episode 961: Total Reward: 269.770, Epsilon: 0.050, Steps: 414, Time: 2.11s
# Episode 971: Total Reward: 98.084, Epsilon: 0.050, Steps: 1000, Time: 4.91s
# Episode 981: Total Reward: 147.900, Epsilon: 0.050, Steps: 1000, Time: 5.44s
# Episode 991: Total Reward: 242.351, Epsilon: 0.050, Steps: 336, Time: 1.83s
# Episode 1001: Total Reward: 221.358, Epsilon: 0.050, Steps: 243, Time: 1.35s
# Checkpoint Reached!
# Episode 1011: Total Reward: -87.780, Epsilon: 0.050, Steps: 1000, Time: 5.15s
# Episode 1021: Total Reward: 176.927, Epsilon: 0.050, Steps: 1000, Time: 4.02s
# Episode 1031: Total Reward: 214.438, Epsilon: 0.050, Steps: 475, Time: 2.04s
# Episode 1041: Total Reward: 259.888, Epsilon: 0.050, Steps: 233, Time: 1.65s
# Episode 1051: Total Reward: 277.067, Epsilon: 0.050, Steps: 340, Time: 2.33s
# Early stopping condition met! Stopping training.
# Episode 1058: Total Reward: 289.240, Epsilon: 0.050, Steps: 309, Time: 2.03s

# %% [markdown]
# ## Training Results

# %%
results = torch.load("dueling_dqn_lunar_lander_v3_checkpoint.pth", weights_only=False)

rewards_per_episode = results["rewards_per_episode"]
epsilon_values = results["epsilon_values"]
steps_per_episode = results["steps_per_episode"]

plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(epsilon_values)
plt.title("Epsilon Values - Training")
plt.xlabel("Episode")
plt.ylabel("Epsilon")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## LunarLander-v3 - Evaluation

# %%
steps_arr = []
rewards_arr = []

env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

state_dim = lunar_env.observation_space.shape[0]
action_dim = lunar_env.action_space.n

trained_agent = DuelingDQNAgent(state_dim, action_dim)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_agent.policy_net.load_state_dict(torch.load("dueling_ddqn_lunar_lander_v3.pth", map_location=device, weights_only=True))

for episode in range(10):
    obs, _ = lunar_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action = trained_agent.select_greedy_action(state)
        obs, reward, done, truncated, _ = lunar_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = 236.61351168385258, Steps taken: 265
# Episode 2: Total Reward = 245.01233557948544, Steps taken: 321
# Episode 3: Total Reward = 264.3515444449109, Steps taken: 271
# Episode 4: Total Reward = 237.5290411944243, Steps taken: 227
# Episode 5: Total Reward = 261.7374380052622, Steps taken: 263
# Episode 6: Total Reward = 269.6448229712705, Steps taken: 280
# Episode 7: Total Reward = 250.1987485241345, Steps taken: 319
# Episode 8: Total Reward = 299.91296613014066, Steps taken: 258
# Episode 9: Total Reward = 290.408191859295, Steps taken: 313
# Episode 10: Total Reward = 294.07432627179605, Steps taken: 306
#
# Average reward over 10 episodes: 264.94829266645723
# Average steps taken over 10 episodes: 282.3
