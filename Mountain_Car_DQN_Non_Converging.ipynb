# %% [markdown]
# # Mountain Car DQN

# %% [markdown]
# ## Imports

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Class definition

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 12)
        self.fc2 = nn.Linear(12, 8)
        self.fc3 = nn.Linear(8, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# DQN Agent
class DQNAgent:
    BATCH_SIZE = 32
    EPSILON_START = 1
    EPSILON_CUTOFF = 0.0
    EPSILON_DECAY = 0.987
    GAMMA = 0.9
    LR = 75e-5
    MEMORY_SIZE = 10000

    def __init__(self, env):
        state_dim = env.observation_space.shape[0]
        action_dim = env.action_space.n
        
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = ReplayBuffer(self.MEMORY_SIZE)
        self.epsilon = self.EPSILON_START
        self.total_steps = 0

    def select_e_greedy_action(self, env, state):
        if random.random() < self.epsilon:
            return random.randint(0, env.action_space.n - 1)
        else:
            state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state).argmax(dim=1).item()

    def select_greedy_action(self, state):
        state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
        with torch.no_grad():
            return self.policy_net(state).argmax(dim=1).item()

    def decay_epsilon(self):
        self.total_steps += 1
        self.epsilon = max(self.EPSILON_CUTOFF, self.epsilon * self.EPSILON_DECAY)

    def step(self):
        if len(self.memory) < self.BATCH_SIZE:
            return
        batch = self.memory.sample(self.BATCH_SIZE)

        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(np.array(actions), dtype=torch.int64, device=self.device).unsqueeze(1)
        rewards = torch.tensor(np.array(rewards), dtype=torch.float32, device=self.device).unsqueeze(1)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=self.device)
        dones = torch.tensor(np.array(dones), dtype=torch.float32, device=self.device).unsqueeze(1)
        current_q = self.policy_net(states).gather(1, actions)
        next_q = self.target_net(next_states).max(1, keepdim=True)[0].detach()
        target_q = rewards + (self.GAMMA * next_q * (1 - dones))

        loss = F.mse_loss(target_q, current_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %% [markdown]
# ## Training function

# %%
def train_q_values(env, env_name, target_update_interval=1000, training_episodes=1000, agent_class=DQNAgent):
    OBS_HIGH_VALUES = env.observation_space.high
    CONVERGENCE_TOLERANCE = 0.001
    GOAL_X_VALUE = 0.5
    
    agent = agent_class(env)
    rewards_per_episode = []
    steps_per_episode = []
    epsilon_values = []
    episode_times = []
    start_episode = 0

    for episode in range(start_episode, training_episodes):
        start_time = time.time()
        obs, _ = env.reset()
        state = obs
        total_reward = 0
        episode_over = False
        steps_taken = 0
        episode_transitions = []

        epsilon_values.append(agent.epsilon)

        while not episode_over:
            action = agent.select_e_greedy_action(env, state)
            obs, reward, done, truncated, _ = env.step(action)
            next_state = np.array(obs, dtype=np.float32)
            
            reward += 2 ** (abs(next_state[1]) * 100)
            reward += 10000000 if next_state[0] >= GOAL_X_VALUE else 0

            agent.memory.push(state, action, reward, next_state, done)
            
            episode_over = done or truncated
            state = next_state
            total_reward += reward
            steps_taken += 1
            
            agent.step()
            
            if agent.total_steps % target_update_interval == 0:
                agent.update_target_network()

        if steps_taken <= 110 and abs(agent.epsilon - agent.EPSILON_CUTOFF) <= CONVERGENCE_TOLERANCE:
            print("Early stopping condition met! Stopping training.")
            print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
            break
        
        agent.decay_epsilon()
        rewards_per_episode.append(total_reward)
        steps_per_episode.append(steps_taken)
        end_time = time.time()
        episode_time = end_time - start_time
        episode_times.append(episode_time)

        if episode % 10 == 0:
            print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        if episode % 100 == 0:
            # Saving model
            checkpoint = {
                'policy_net_state_dict': agent.policy_net.state_dict(),
                'optimizer_state_dict': agent.optimizer.state_dict(),
                'total_steps': agent.total_steps,
                'current_episode': episode,
                'rewards_per_episode': rewards_per_episode,
                'epsilon_values': epsilon_values,
                'episode_times': episode_times,
                'steps_per_episode': steps_per_episode
            }
            torch.save(checkpoint, "dqn_mountain_car_env_v0_checkpoint.pth")
            torch.save(agent.policy_net.state_dict(), "dqn_mountain_car_env_v0.pth")
            print("Checkpoint Reached!")
    
    return agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode

# %% [markdown]
# ## Mountain Car Training

# %%
env_name = "MountainCar-v0"
mountain_env = gym.make(env_name, max_episode_steps=1000, render_mode="rgb_array")

trained_agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode = train_q_values(mountain_env, env_name, training_episodes=1500)
checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'total_steps': trained_agent.total_steps,
    'rewards_per_episode': rewards_per_episode,
    'epsilon_values': epsilon_values,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}
torch.save(checkpoint, "dqn_mountain_car_env_v0_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "dqn_mountain_car_env_v0.pth")
# Out:
# Episode 1: Total Reward: 857.229, Epsilon: 0.987, Steps: 1000, Time: 1.51s
# Checkpoint Reached!
# Episode 11: Total Reward: 1119.723, Epsilon: 0.866, Steps: 1000, Time: 1.49s
# Episode 21: Total Reward: 801.331, Epsilon: 0.760, Steps: 1000, Time: 1.56s
# Episode 31: Total Reward: 1659.213, Epsilon: 0.667, Steps: 1000, Time: 1.43s
# Episode 41: Total Reward: 1163.717, Epsilon: 0.585, Steps: 1000, Time: 1.44s
# Episode 51: Total Reward: 71.987, Epsilon: 0.513, Steps: 1000, Time: 1.50s
# Episode 61: Total Reward: 1165.558, Epsilon: 0.450, Steps: 1000, Time: 1.79s
# Episode 71: Total Reward: 819.772, Epsilon: 0.395, Steps: 1000, Time: 1.70s
# Episode 81: Total Reward: 2447.591, Epsilon: 0.346, Steps: 1000, Time: 1.61s
# Episode 91: Total Reward: 3066.728, Epsilon: 0.304, Steps: 1000, Time: 1.56s
# Episode 101: Total Reward: 1892.971, Epsilon: 0.267, Steps: 1000, Time: 1.60s
# Checkpoint Reached!
# Episode 111: Total Reward: 10003368.046, Epsilon: 0.234, Steps: 820, Time: 1.41s
# Episode 121: Total Reward: 1487.357, Epsilon: 0.205, Steps: 1000, Time: 1.57s
# Episode 131: Total Reward: 471.264, Epsilon: 0.180, Steps: 1000, Time: 1.53s
# Episode 141: Total Reward: 400.426, Epsilon: 0.158, Steps: 1000, Time: 1.67s
# Episode 151: Total Reward: 203.752, Epsilon: 0.139, Steps: 1000, Time: 1.54s
# Episode 161: Total Reward: 7703.438, Epsilon: 0.122, Steps: 1000, Time: 1.69s
# Episode 171: Total Reward: 138.648, Epsilon: 0.107, Steps: 1000, Time: 1.94s
# Episode 181: Total Reward: 8229.533, Epsilon: 0.094, Steps: 1000, Time: 1.66s
# Episode 191: Total Reward: 4642.575, Epsilon: 0.082, Steps: 1000, Time: 1.61s
# Episode 201: Total Reward: 57.709, Epsilon: 0.072, Steps: 1000, Time: 1.79s
# Checkpoint Reached!
# Episode 211: Total Reward: 38.184, Epsilon: 0.063, Steps: 1000, Time: 1.90s
# Episode 221: Total Reward: 44.325, Epsilon: 0.055, Steps: 1000, Time: 1.98s
# Episode 231: Total Reward: 37.806, Epsilon: 0.049, Steps: 1000, Time: 2.03s
# Episode 241: Total Reward: 34.439, Epsilon: 0.043, Steps: 1000, Time: 1.66s
# Episode 251: Total Reward: 182.998, Epsilon: 0.037, Steps: 1000, Time: 1.86s
# Episode 261: Total Reward: 824.702, Epsilon: 0.033, Steps: 1000, Time: 1.69s
# Episode 271: Total Reward: 10132.424, Epsilon: 0.029, Steps: 1000, Time: 1.98s
# Episode 281: Total Reward: 11235.042, Epsilon: 0.025, Steps: 1000, Time: 1.69s
# Episode 291: Total Reward: 784.159, Epsilon: 0.022, Steps: 1000, Time: 1.67s
# Episode 301: Total Reward: 528.514, Epsilon: 0.019, Steps: 1000, Time: 1.66s
# Checkpoint Reached!
# Episode 311: Total Reward: 6059.238, Epsilon: 0.017, Steps: 1000, Time: 1.56s
# Episode 321: Total Reward: 2551.411, Epsilon: 0.015, Steps: 1000, Time: 1.75s
# Episode 331: Total Reward: 1763.721, Epsilon: 0.013, Steps: 1000, Time: 1.69s
# Episode 341: Total Reward: 7520.564, Epsilon: 0.012, Steps: 1000, Time: 1.75s
# Episode 351: Total Reward: 243.621, Epsilon: 0.010, Steps: 1000, Time: 1.64s
# Episode 361: Total Reward: 6849.361, Epsilon: 0.009, Steps: 1000, Time: 2.40s
# Episode 371: Total Reward: 7388.826, Epsilon: 0.008, Steps: 1000, Time: 2.02s
# Episode 381: Total Reward: 55.109, Epsilon: 0.007, Steps: 1000, Time: 1.64s
# Episode 391: Total Reward: 147.099, Epsilon: 0.006, Steps: 1000, Time: 1.60s
# Episode 401: Total Reward: 240.281, Epsilon: 0.005, Steps: 1000, Time: 1.98s
# Checkpoint Reached!
# Episode 411: Total Reward: 8514.197, Epsilon: 0.005, Steps: 1000, Time: 1.78s
# Episode 421: Total Reward: 736.271, Epsilon: 0.004, Steps: 1000, Time: 1.63s
# Episode 431: Total Reward: 236.582, Epsilon: 0.004, Steps: 1000, Time: 2.07s
# Episode 441: Total Reward: 458.443, Epsilon: 0.003, Steps: 1000, Time: 1.77s
# Episode 451: Total Reward: 6333.347, Epsilon: 0.003, Steps: 1000, Time: 1.56s
# Episode 461: Total Reward: 429.113, Epsilon: 0.002, Steps: 1000, Time: 1.54s
# Episode 471: Total Reward: 145.695, Epsilon: 0.002, Steps: 1000, Time: 1.62s
# Episode 481: Total Reward: 232.215, Epsilon: 0.002, Steps: 1000, Time: 1.69s
# Episode 491: Total Reward: 5025.094, Epsilon: 0.002, Steps: 1000, Time: 1.56s
# Episode 501: Total Reward: 181.489, Epsilon: 0.001, Steps: 1000, Time: 1.58s
# Checkpoint Reached!
# Episode 511: Total Reward: 569.599, Epsilon: 0.001, Steps: 1000, Time: 1.49s
# Episode 521: Total Reward: 4099.600, Epsilon: 0.001, Steps: 1000, Time: 1.50s
# Episode 531: Total Reward: 685.228, Epsilon: 0.001, Steps: 1000, Time: 1.51s
# Episode 541: Total Reward: 121.632, Epsilon: 0.001, Steps: 1000, Time: 1.52s
# Episode 551: Total Reward: 8000.722, Epsilon: 0.001, Steps: 1000, Time: 1.61s
# Episode 561: Total Reward: 150.966, Epsilon: 0.001, Steps: 1000, Time: 1.52s
# Episode 571: Total Reward: 300.871, Epsilon: 0.001, Steps: 1000, Time: 1.56s
# Episode 581: Total Reward: 429.437, Epsilon: 0.000, Steps: 1000, Time: 1.56s
# Episode 591: Total Reward: 10642.990, Epsilon: 0.000, Steps: 1000, Time: 1.56s
# Episode 601: Total Reward: 9933.377, Epsilon: 0.000, Steps: 1000, Time: 1.57s
# Checkpoint Reached!
# Episode 611: Total Reward: 498.936, Epsilon: 0.000, Steps: 1000, Time: 1.50s
# Episode 621: Total Reward: 10133.620, Epsilon: 0.000, Steps: 1000, Time: 1.70s
# Episode 631: Total Reward: 565.949, Epsilon: 0.000, Steps: 1000, Time: 1.77s
# Episode 641: Total Reward: 10668.141, Epsilon: 0.000, Steps: 1000, Time: 1.76s
# Episode 651: Total Reward: 4547.848, Epsilon: 0.000, Steps: 1000, Time: 1.64s
# Episode 661: Total Reward: 388.531, Epsilon: 0.000, Steps: 1000, Time: 1.44s
# Episode 671: Total Reward: 377.533, Epsilon: 0.000, Steps: 1000, Time: 1.58s
# Episode 681: Total Reward: 622.292, Epsilon: 0.000, Steps: 1000, Time: 1.53s
# Episode 691: Total Reward: 1101.528, Epsilon: 0.000, Steps: 1000, Time: 1.67s
# Episode 701: Total Reward: 575.520, Epsilon: 0.000, Steps: 1000, Time: 1.95s
# Checkpoint Reached!
# Episode 711: Total Reward: 348.537, Epsilon: 0.000, Steps: 1000, Time: 1.57s
# Episode 721: Total Reward: 261.200, Epsilon: 0.000, Steps: 1000, Time: 1.78s
# Episode 731: Total Reward: 205.987, Epsilon: 0.000, Steps: 1000, Time: 1.67s
# Episode 741: Total Reward: 254.149, Epsilon: 0.000, Steps: 1000, Time: 1.52s
# Episode 751: Total Reward: 405.897, Epsilon: 0.000, Steps: 1000, Time: 1.51s
# Episode 761: Total Reward: 8899.811, Epsilon: 0.000, Steps: 1000, Time: 1.97s
# Episode 771: Total Reward: 701.233, Epsilon: 0.000, Steps: 1000, Time: 1.59s
# Episode 781: Total Reward: 99.843, Epsilon: 0.000, Steps: 1000, Time: 1.61s
# Episode 791: Total Reward: 392.076, Epsilon: 0.000, Steps: 1000, Time: 1.55s
# Episode 801: Total Reward: 860.756, Epsilon: 0.000, Steps: 1000, Time: 2.10s
# Checkpoint Reached!
# Episode 811: Total Reward: 988.374, Epsilon: 0.000, Steps: 1000, Time: 1.89s
# Episode 821: Total Reward: 111.677, Epsilon: 0.000, Steps: 1000, Time: 1.72s
# Episode 831: Total Reward: 247.586, Epsilon: 0.000, Steps: 1000, Time: 1.67s
# Episode 841: Total Reward: 13900.330, Epsilon: 0.000, Steps: 1000, Time: 1.67s
# Episode 851: Total Reward: 572.094, Epsilon: 0.000, Steps: 1000, Time: 2.12s
# Episode 861: Total Reward: 552.079, Epsilon: 0.000, Steps: 1000, Time: 1.75s
# Episode 871: Total Reward: 152.984, Epsilon: 0.000, Steps: 1000, Time: 1.75s
# Episode 881: Total Reward: 180.989, Epsilon: 0.000, Steps: 1000, Time: 1.65s
# Episode 891: Total Reward: 598.401, Epsilon: 0.000, Steps: 1000, Time: 1.70s
# Episode 901: Total Reward: 579.940, Epsilon: 0.000, Steps: 1000, Time: 1.73s
# Checkpoint Reached!
# Episode 911: Total Reward: 783.480, Epsilon: 0.000, Steps: 1000, Time: 1.67s
# Episode 921: Total Reward: 452.818, Epsilon: 0.000, Steps: 1000, Time: 1.68s
# Episode 931: Total Reward: 270.013, Epsilon: 0.000, Steps: 1000, Time: 1.63s
# Episode 941: Total Reward: 745.861, Epsilon: 0.000, Steps: 1000, Time: 1.62s
# Episode 951: Total Reward: 1028.410, Epsilon: 0.000, Steps: 1000, Time: 1.77s
# Episode 961: Total Reward: 775.138, Epsilon: 0.000, Steps: 1000, Time: 2.37s
# Episode 971: Total Reward: 251.575, Epsilon: 0.000, Steps: 1000, Time: 1.76s
# Episode 981: Total Reward: 1232.050, Epsilon: 0.000, Steps: 1000, Time: 1.55s
# Episode 991: Total Reward: 1134.804, Epsilon: 0.000, Steps: 1000, Time: 1.55s
# Episode 1001: Total Reward: 1259.089, Epsilon: 0.000, Steps: 1000, Time: 2.00s
# Checkpoint Reached!
# Episode 1011: Total Reward: 1184.168, Epsilon: 0.000, Steps: 1000, Time: 1.53s
# Episode 1021: Total Reward: 154.527, Epsilon: 0.000, Steps: 1000, Time: 1.55s
# Episode 1031: Total Reward: 436.323, Epsilon: 0.000, Steps: 1000, Time: 1.53s
# Episode 1041: Total Reward: 156.306, Epsilon: 0.000, Steps: 1000, Time: 1.48s
# Episode 1051: Total Reward: 1206.918, Epsilon: 0.000, Steps: 1000, Time: 1.69s
# Episode 1061: Total Reward: 760.778, Epsilon: 0.000, Steps: 1000, Time: 1.56s
# Episode 1071: Total Reward: 900.256, Epsilon: 0.000, Steps: 1000, Time: 1.55s
# Episode 1081: Total Reward: 1215.197, Epsilon: 0.000, Steps: 1000, Time: 1.53s
# Episode 1091: Total Reward: 211.007, Epsilon: 0.000, Steps: 1000, Time: 1.51s
# Episode 1101: Total Reward: 463.999, Epsilon: 0.000, Steps: 1000, Time: 1.52s
# Checkpoint Reached!
# Episode 1111: Total Reward: 173.811, Epsilon: 0.000, Steps: 1000, Time: 1.61s
# Episode 1121: Total Reward: 840.202, Epsilon: 0.000, Steps: 1000, Time: 1.59s
# Episode 1131: Total Reward: 884.473, Epsilon: 0.000, Steps: 1000, Time: 1.57s
# Episode 1141: Total Reward: 367.172, Epsilon: 0.000, Steps: 1000, Time: 1.51s
# Episode 1151: Total Reward: 956.460, Epsilon: 0.000, Steps: 1000, Time: 1.62s
# Episode 1161: Total Reward: 571.529, Epsilon: 0.000, Steps: 1000, Time: 1.57s
# Episode 1171: Total Reward: 1329.347, Epsilon: 0.000, Steps: 1000, Time: 1.63s
# Episode 1181: Total Reward: 1068.672, Epsilon: 0.000, Steps: 1000, Time: 2.02s
# Episode 1191: Total Reward: 381.926, Epsilon: 0.000, Steps: 1000, Time: 2.31s
# Episode 1201: Total Reward: 588.318, Epsilon: 0.000, Steps: 1000, Time: 2.07s
# Checkpoint Reached!
# Episode 1211: Total Reward: 1125.361, Epsilon: 0.000, Steps: 1000, Time: 2.13s
# Episode 1221: Total Reward: 116.948, Epsilon: 0.000, Steps: 1000, Time: 1.77s
# Episode 1231: Total Reward: 130.396, Epsilon: 0.000, Steps: 1000, Time: 1.80s
# Episode 1241: Total Reward: 149.042, Epsilon: 0.000, Steps: 1000, Time: 1.78s
# Episode 1251: Total Reward: 141.852, Epsilon: 0.000, Steps: 1000, Time: 1.81s
# Episode 1261: Total Reward: 112.024, Epsilon: 0.000, Steps: 1000, Time: 1.76s
# Episode 1271: Total Reward: 357.304, Epsilon: 0.000, Steps: 1000, Time: 1.97s
# Episode 1281: Total Reward: 717.357, Epsilon: 0.000, Steps: 1000, Time: 1.87s
# Episode 1291: Total Reward: 654.999, Epsilon: 0.000, Steps: 1000, Time: 1.69s
# Episode 1301: Total Reward: 154.549, Epsilon: 0.000, Steps: 1000, Time: 1.80s
# Checkpoint Reached!
# Episode 1311: Total Reward: 143.181, Epsilon: 0.000, Steps: 1000, Time: 1.71s
# Episode 1321: Total Reward: 481.931, Epsilon: 0.000, Steps: 1000, Time: 1.77s
# Episode 1331: Total Reward: 305.930, Epsilon: 0.000, Steps: 1000, Time: 1.79s
# Episode 1341: Total Reward: 297.004, Epsilon: 0.000, Steps: 1000, Time: 1.82s
# Episode 1351: Total Reward: 405.782, Epsilon: 0.000, Steps: 1000, Time: 1.71s
# Episode 1361: Total Reward: 396.119, Epsilon: 0.000, Steps: 1000, Time: 1.82s
# Episode 1371: Total Reward: 707.083, Epsilon: 0.000, Steps: 1000, Time: 1.86s
# Episode 1381: Total Reward: 1240.824, Epsilon: 0.000, Steps: 1000, Time: 1.87s
# Episode 1391: Total Reward: 738.572, Epsilon: 0.000, Steps: 1000, Time: 1.75s
# Episode 1401: Total Reward: 668.741, Epsilon: 0.000, Steps: 1000, Time: 1.70s
# Checkpoint Reached!
# Episode 1411: Total Reward: 241.957, Epsilon: 0.000, Steps: 1000, Time: 1.81s
# Episode 1421: Total Reward: 877.554, Epsilon: 0.000, Steps: 1000, Time: 1.71s
# Episode 1431: Total Reward: 1189.664, Epsilon: 0.000, Steps: 1000, Time: 1.78s
# Episode 1441: Total Reward: 88.916, Epsilon: 0.000, Steps: 1000, Time: 1.73s
# Episode 1451: Total Reward: 638.265, Epsilon: 0.000, Steps: 1000, Time: 1.96s
# Episode 1461: Total Reward: 1075.642, Epsilon: 0.000, Steps: 1000, Time: 1.78s
# Episode 1471: Total Reward: 422.290, Epsilon: 0.000, Steps: 1000, Time: 1.87s
# Episode 1481: Total Reward: 465.360, Epsilon: 0.000, Steps: 1000, Time: 1.80s
# Episode 1491: Total Reward: 1355.936, Epsilon: 0.000, Steps: 1000, Time: 1.95s

# %% [markdown]
# ## Training Results

# %%
plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## Mountain Car Evaluation

# %%
steps_arr = []
rewards_arr = []

for episode in range(10):
    obs, _ = mountain_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action = trained_agent.select_greedy_action(state)
        obs, reward, done, truncated, _ = mountain_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = -1000.0, Steps taken: 1000
# Episode 2: Total Reward = -1000.0, Steps taken: 1000
# Episode 3: Total Reward = -1000.0, Steps taken: 1000
# Episode 4: Total Reward = -1000.0, Steps taken: 1000
# Episode 5: Total Reward = -1000.0, Steps taken: 1000
# Episode 6: Total Reward = -1000.0, Steps taken: 1000
# Episode 7: Total Reward = -1000.0, Steps taken: 1000
# Episode 8: Total Reward = -1000.0, Steps taken: 1000
# Episode 9: Total Reward = -1000.0, Steps taken: 1000
# Episode 10: Total Reward = -1000.0, Steps taken: 1000
#
# Average reward over 10 episodes: -1000.0
# Average steps taken over 10 episodes: 1000.0
