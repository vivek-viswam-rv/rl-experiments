# %% [markdown]
# # Lunar Lander - DQN

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## DQN Agent-related Class Definitions

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DQNAgent:
    BATCH_SIZE = 32
    EPSILON_START = 1
    EPSILON_CUTOFF = 0.05
    EPSILON_DECAY = 100000
    GAMMA = 0.99
    LR = 1e-4
    MEMORY_SIZE = 10000
    total_steps = 0

    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = ReplayBuffer(self.MEMORY_SIZE)
        self.steps_done = 0
        self.epsilon = self.EPSILON_START

    def select_e_greedy_action(self, env, state):
        if random.random() < self.epsilon:
            return random.randint(0, env.action_space.n - 1)
        else:
            state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state).argmax(dim=1).item()

    def select_greedy_action(self, state):
      state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
      with torch.no_grad():
          return self.policy_net(state).argmax(dim=1).item()

    def decay_epsilon(self):
      self.total_steps += 1
      self.epsilon = max(self.EPSILON_CUTOFF, self.EPSILON_START - (self.total_steps / self.EPSILON_DECAY))

    def train(self):
        if len(self.memory) < self.BATCH_SIZE:
            return
        batch = self.memory.sample(self.BATCH_SIZE)

        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(np.array(actions), dtype=torch.int64, device=self.device).unsqueeze(1)
        rewards = torch.tensor(np.array(rewards), dtype=torch.float32, device=self.device).unsqueeze(1)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=self.device)
        dones = torch.tensor(np.array(dones), dtype=torch.float32, device=self.device).unsqueeze(1)
        current_q = self.policy_net(states).gather(1, actions)
        next_q = self.target_net(next_states).max(1, keepdim=True)[0].detach()
        target_q = rewards + (self.GAMMA * next_q * (1 - dones))

        loss = F.mse_loss(target_q, current_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %% [markdown]
# ## Training Function Definition

# %%
def train_q_values(env, env_name,target_update_interval = 10, training_episodes = 1000, agent_class = DQNAgent):
  MAX_STEPS = 1000
  CONVERGENCE_REWARD_COUNT = 20
  CONVERGENCE_MIN_REWARD = 270

  state_dim = env.observation_space.shape[0]
  action_dim = env.action_space.n
  agent = agent_class(state_dim, action_dim)
  rewards_per_episode = []
  episode_times = []
  steps_per_episode = []
  epsilon_values = []

  for episode in range(training_episodes):
    start_time = time.time()
    obs, _ = env.reset()
    state = obs
    total_reward = 0
    done = False
    steps_taken = 0
    episode_transitions = []

    epsilon_values.append(agent.epsilon)

    while not done and steps_taken < MAX_STEPS:
        action = agent.select_e_greedy_action(env, state)
        obs, reward, done, _, _ = env.step(action)
        next_state = np.array(obs, dtype=np.float32)
        episode_transitions.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        steps_taken += 1

        agent.decay_epsilon()

    average_rewards_over_last_episodes = np.mean(rewards_per_episode[-CONVERGENCE_REWARD_COUNT:])

    if average_rewards_over_last_episodes >= CONVERGENCE_MIN_REWARD and total_reward >= CONVERGENCE_MIN_REWARD:
        print("Early stopping condition met! Stopping training.")
        print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        break
      
    for transition in episode_transitions:
        agent.memory.push(*transition)

    for _ in range(len(episode_transitions)):
        agent.train()

    end_time = time.time()
    episode_time = end_time - start_time
    episode_times.append(episode_time)
    rewards_per_episode.append(total_reward)
    steps_per_episode.append(steps_taken)

    if episode % target_update_interval == 0:
      agent.update_target_network()

    if episode % 10 == 0:
      print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")

    if episode % 100 == 0:
      checkpoint = {
        'policy_net_state_dict': agent.policy_net.state_dict(),
        'optimizer_state_dict': agent.optimizer.state_dict(),
        'total_steps': agent.total_steps,
        'rewards_per_episode': rewards_per_episode,
        'epsilon_values': epsilon_values,
        'episode_times': episode_times,
        'steps_per_episode': steps_per_episode
      }

      torch.save(checkpoint, "dqn_lunar_lander_v3_checkpoint.pth")
      torch.save(agent.policy_net.state_dict(), "dqn_lunar_lander_v3.pth")
      print("Checkpoint Reached!")

  return agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode

# %% [markdown]
# ## LunarLander-v3 - Training

# %%
env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

trained_agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode = train_q_values(lunar_env, env_name, training_episodes = 2000)

checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'total_steps': trained_agent.total_steps,
    'rewards_per_episode': rewards_per_episode,
    'epsilon_values': epsilon_values,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}

torch.save(checkpoint, "dqn_lunar_lander_v3_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "dqn_lunar_lander_v3.pth")
# Out:
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 1: Total Reward: -92.022, Epsilon: 0.999, Steps: 69, Time: 0.18s
# Checkpoint Reached!
# Episode 11: Total Reward: -120.679, Epsilon: 0.990, Steps: 93, Time: 0.21s
# Episode 21: Total Reward: -94.423, Epsilon: 0.979, Steps: 75, Time: 0.18s
# Episode 31: Total Reward: -123.970, Epsilon: 0.970, Steps: 113, Time: 0.34s
# Episode 41: Total Reward: -131.750, Epsilon: 0.961, Steps: 92, Time: 0.29s
# Episode 51: Total Reward: -360.654, Epsilon: 0.952, Steps: 125, Time: 0.35s
# Episode 61: Total Reward: -147.697, Epsilon: 0.942, Steps: 87, Time: 0.26s
# Episode 71: Total Reward: -206.483, Epsilon: 0.931, Steps: 107, Time: 0.34s
# Episode 81: Total Reward: -132.531, Epsilon: 0.921, Steps: 112, Time: 0.36s
# Episode 91: Total Reward: -199.166, Epsilon: 0.911, Steps: 114, Time: 0.35s
# Episode 101: Total Reward: -161.522, Epsilon: 0.902, Steps: 103, Time: 0.32s
# Checkpoint Reached!
# Episode 111: Total Reward: -287.320, Epsilon: 0.893, Steps: 81, Time: 0.26s
# Episode 121: Total Reward: -193.375, Epsilon: 0.883, Steps: 117, Time: 0.36s
# Episode 131: Total Reward: -189.503, Epsilon: 0.873, Steps: 78, Time: 0.25s
# Episode 141: Total Reward: -139.563, Epsilon: 0.862, Steps: 106, Time: 0.32s
# Episode 151: Total Reward: -131.362, Epsilon: 0.851, Steps: 139, Time: 0.41s
# Episode 161: Total Reward: -109.600, Epsilon: 0.841, Steps: 79, Time: 0.23s
# Episode 171: Total Reward: -198.517, Epsilon: 0.831, Steps: 122, Time: 0.38s
# Episode 181: Total Reward: -97.222, Epsilon: 0.821, Steps: 104, Time: 0.36s
# Episode 191: Total Reward: -69.370, Epsilon: 0.811, Steps: 141, Time: 0.44s
# Episode 201: Total Reward: -90.686, Epsilon: 0.801, Steps: 66, Time: 0.21s
# Checkpoint Reached!
# Episode 211: Total Reward: -154.059, Epsilon: 0.789, Steps: 118, Time: 0.25s
# Episode 221: Total Reward: -71.657, Epsilon: 0.779, Steps: 97, Time: 0.20s
# Episode 231: Total Reward: -97.697, Epsilon: 0.769, Steps: 80, Time: 0.19s
# Episode 241: Total Reward: -108.084, Epsilon: 0.759, Steps: 91, Time: 0.19s
# Episode 251: Total Reward: 21.715, Epsilon: 0.749, Steps: 80, Time: 0.17s
# Episode 261: Total Reward: -78.703, Epsilon: 0.738, Steps: 110, Time: 0.25s
# Episode 271: Total Reward: -136.334, Epsilon: 0.728, Steps: 119, Time: 0.25s
# Episode 281: Total Reward: -119.186, Epsilon: 0.716, Steps: 143, Time: 0.30s
# Episode 291: Total Reward: -106.122, Epsilon: 0.706, Steps: 145, Time: 0.32s
# Episode 301: Total Reward: -58.898, Epsilon: 0.695, Steps: 64, Time: 0.14s
# Checkpoint Reached!
# Episode 311: Total Reward: -38.618, Epsilon: 0.684, Steps: 88, Time: 0.19s
# Episode 321: Total Reward: -69.330, Epsilon: 0.672, Steps: 87, Time: 0.19s
# Episode 331: Total Reward: -82.178, Epsilon: 0.660, Steps: 133, Time: 0.32s
# Episode 341: Total Reward: -50.070, Epsilon: 0.647, Steps: 88, Time: 0.21s
# Episode 351: Total Reward: -92.575, Epsilon: 0.634, Steps: 126, Time: 0.26s
# Episode 361: Total Reward: -143.705, Epsilon: 0.622, Steps: 90, Time: 0.21s
# Episode 371: Total Reward: -196.685, Epsilon: 0.608, Steps: 136, Time: 0.31s
# Episode 381: Total Reward: -28.803, Epsilon: 0.595, Steps: 90, Time: 0.20s
# Episode 391: Total Reward: -36.911, Epsilon: 0.571, Steps: 75, Time: 0.17s
# Episode 401: Total Reward: -190.075, Epsilon: 0.550, Steps: 578, Time: 1.26s
# Checkpoint Reached!
# Episode 411: Total Reward: -38.793, Epsilon: 0.525, Steps: 322, Time: 0.69s
# Episode 421: Total Reward: -29.878, Epsilon: 0.486, Steps: 178, Time: 0.44s
# Episode 431: Total Reward: -337.011, Epsilon: 0.439, Steps: 602, Time: 1.30s
# Episode 441: Total Reward: -256.356, Epsilon: 0.346, Steps: 963, Time: 2.25s
# Episode 451: Total Reward: -202.564, Epsilon: 0.247, Steps: 895, Time: 2.06s
# Episode 461: Total Reward: -85.011, Epsilon: 0.154, Steps: 1000, Time: 2.47s
# Episode 471: Total Reward: -63.101, Epsilon: 0.054, Steps: 1000, Time: 2.63s
# Episode 481: Total Reward: -103.145, Epsilon: 0.050, Steps: 1000, Time: 2.58s
# Episode 491: Total Reward: -60.262, Epsilon: 0.050, Steps: 1000, Time: 2.84s
# Episode 501: Total Reward: -7.790, Epsilon: 0.050, Steps: 1000, Time: 2.52s
# Checkpoint Reached!
# Episode 511: Total Reward: -139.084, Epsilon: 0.050, Steps: 395, Time: 0.93s
# Episode 521: Total Reward: 2.970, Epsilon: 0.050, Steps: 1000, Time: 2.39s
# Episode 531: Total Reward: -90.488, Epsilon: 0.050, Steps: 1000, Time: 2.57s
# Episode 541: Total Reward: -33.749, Epsilon: 0.050, Steps: 1000, Time: 2.59s
# Episode 551: Total Reward: -15.276, Epsilon: 0.050, Steps: 1000, Time: 2.53s
# Episode 561: Total Reward: -54.688, Epsilon: 0.050, Steps: 1000, Time: 2.62s
# Episode 571: Total Reward: -40.473, Epsilon: 0.050, Steps: 1000, Time: 2.55s
# Episode 581: Total Reward: -55.232, Epsilon: 0.050, Steps: 1000, Time: 2.54s
# Episode 591: Total Reward: -69.706, Epsilon: 0.050, Steps: 1000, Time: 2.58s
# Episode 601: Total Reward: -0.813, Epsilon: 0.050, Steps: 1000, Time: 2.42s
# Checkpoint Reached!
# Episode 611: Total Reward: -136.083, Epsilon: 0.050, Steps: 866, Time: 1.97s
# Episode 621: Total Reward: -45.828, Epsilon: 0.050, Steps: 1000, Time: 2.43s
# Episode 631: Total Reward: -204.959, Epsilon: 0.050, Steps: 804, Time: 2.25s
# Episode 641: Total Reward: -98.465, Epsilon: 0.050, Steps: 1000, Time: 3.26s
# Episode 651: Total Reward: -66.060, Epsilon: 0.050, Steps: 1000, Time: 2.63s
# Episode 661: Total Reward: -6.285, Epsilon: 0.050, Steps: 1000, Time: 2.57s
# Episode 671: Total Reward: -118.256, Epsilon: 0.050, Steps: 1000, Time: 2.90s
# Episode 681: Total Reward: -41.108, Epsilon: 0.050, Steps: 1000, Time: 2.46s
# Episode 691: Total Reward: 1.043, Epsilon: 0.050, Steps: 1000, Time: 2.53s
# Episode 701: Total Reward: -12.400, Epsilon: 0.050, Steps: 1000, Time: 2.47s
# Checkpoint Reached!
# Episode 711: Total Reward: -121.467, Epsilon: 0.050, Steps: 363, Time: 0.89s
# Episode 721: Total Reward: -62.945, Epsilon: 0.050, Steps: 1000, Time: 2.60s
# Episode 731: Total Reward: -123.886, Epsilon: 0.050, Steps: 275, Time: 0.67s
# Episode 741: Total Reward: -97.321, Epsilon: 0.050, Steps: 1000, Time: 2.51s
# Episode 751: Total Reward: -31.846, Epsilon: 0.050, Steps: 1000, Time: 2.77s
# Episode 761: Total Reward: -43.182, Epsilon: 0.050, Steps: 1000, Time: 2.82s
# Episode 771: Total Reward: 2.909, Epsilon: 0.050, Steps: 1000, Time: 2.71s
# Episode 781: Total Reward: -111.892, Epsilon: 0.050, Steps: 420, Time: 1.01s
# Episode 791: Total Reward: -21.161, Epsilon: 0.050, Steps: 1000, Time: 2.51s
# Episode 801: Total Reward: 7.526, Epsilon: 0.050, Steps: 1000, Time: 2.54s
# Checkpoint Reached!
# Episode 811: Total Reward: -7.477, Epsilon: 0.050, Steps: 1000, Time: 2.61s
# Episode 821: Total Reward: -65.841, Epsilon: 0.050, Steps: 1000, Time: 3.05s
# Episode 831: Total Reward: 11.271, Epsilon: 0.050, Steps: 1000, Time: 2.44s
# Episode 841: Total Reward: -28.766, Epsilon: 0.050, Steps: 1000, Time: 2.95s
# Episode 851: Total Reward: -25.908, Epsilon: 0.050, Steps: 1000, Time: 2.44s
# Episode 861: Total Reward: -35.818, Epsilon: 0.050, Steps: 1000, Time: 2.98s
# Episode 871: Total Reward: -66.266, Epsilon: 0.050, Steps: 1000, Time: 2.88s
# Episode 881: Total Reward: -26.313, Epsilon: 0.050, Steps: 1000, Time: 2.41s
# Episode 891: Total Reward: -15.528, Epsilon: 0.050, Steps: 1000, Time: 2.41s
# Episode 901: Total Reward: -30.811, Epsilon: 0.050, Steps: 1000, Time: 2.58s
# Checkpoint Reached!
# Episode 911: Total Reward: -20.524, Epsilon: 0.050, Steps: 1000, Time: 2.52s
# Episode 921: Total Reward: -58.008, Epsilon: 0.050, Steps: 263, Time: 0.66s
# Episode 931: Total Reward: 20.923, Epsilon: 0.050, Steps: 1000, Time: 2.73s
# Episode 941: Total Reward: 222.775, Epsilon: 0.050, Steps: 563, Time: 2.07s
# Episode 951: Total Reward: 12.791, Epsilon: 0.050, Steps: 1000, Time: 2.42s
# Episode 961: Total Reward: -27.214, Epsilon: 0.050, Steps: 1000, Time: 2.52s
# Episode 971: Total Reward: -34.095, Epsilon: 0.050, Steps: 1000, Time: 2.51s
# Episode 981: Total Reward: 13.724, Epsilon: 0.050, Steps: 1000, Time: 2.48s
# Episode 991: Total Reward: -10.712, Epsilon: 0.050, Steps: 1000, Time: 2.56s
# Episode 1001: Total Reward: -62.444, Epsilon: 0.050, Steps: 162, Time: 0.39s
# Checkpoint Reached!
# Episode 1011: Total Reward: -22.970, Epsilon: 0.050, Steps: 1000, Time: 2.58s
# Episode 1021: Total Reward: -25.911, Epsilon: 0.050, Steps: 1000, Time: 2.50s
# Episode 1031: Total Reward: 27.098, Epsilon: 0.050, Steps: 1000, Time: 2.57s
# Episode 1041: Total Reward: -2.011, Epsilon: 0.050, Steps: 1000, Time: 2.52s
# Episode 1051: Total Reward: -21.770, Epsilon: 0.050, Steps: 1000, Time: 2.55s
# Episode 1061: Total Reward: -5.059, Epsilon: 0.050, Steps: 1000, Time: 2.44s
# Episode 1071: Total Reward: -111.059, Epsilon: 0.050, Steps: 1000, Time: 2.43s
# Episode 1081: Total Reward: -7.183, Epsilon: 0.050, Steps: 1000, Time: 2.59s
# Episode 1091: Total Reward: -138.668, Epsilon: 0.050, Steps: 53, Time: 0.13s
# Episode 1101: Total Reward: -70.825, Epsilon: 0.050, Steps: 1000, Time: 2.47s
# Checkpoint Reached!
# Episode 1111: Total Reward: -35.307, Epsilon: 0.050, Steps: 1000, Time: 2.60s
# Episode 1121: Total Reward: -6.265, Epsilon: 0.050, Steps: 1000, Time: 2.59s
# Episode 1131: Total Reward: -49.872, Epsilon: 0.050, Steps: 1000, Time: 2.60s
# Episode 1141: Total Reward: -13.526, Epsilon: 0.050, Steps: 1000, Time: 2.70s
# Episode 1151: Total Reward: 10.297, Epsilon: 0.050, Steps: 1000, Time: 2.47s
# Episode 1161: Total Reward: 71.622, Epsilon: 0.050, Steps: 90, Time: 0.23s
# Episode 1171: Total Reward: 10.465, Epsilon: 0.050, Steps: 1000, Time: 2.32s
# Episode 1181: Total Reward: -6.710, Epsilon: 0.050, Steps: 1000, Time: 2.34s
# Episode 1191: Total Reward: 5.720, Epsilon: 0.050, Steps: 1000, Time: 2.55s
# Episode 1201: Total Reward: 2.008, Epsilon: 0.050, Steps: 1000, Time: 2.43s
# Checkpoint Reached!
# Episode 1211: Total Reward: -25.863, Epsilon: 0.050, Steps: 1000, Time: 2.51s
# Episode 1221: Total Reward: 18.270, Epsilon: 0.050, Steps: 1000, Time: 2.45s
# Episode 1231: Total Reward: 7.514, Epsilon: 0.050, Steps: 1000, Time: 2.49s
# Episode 1241: Total Reward: -70.417, Epsilon: 0.050, Steps: 1000, Time: 2.41s
# Episode 1251: Total Reward: -53.116, Epsilon: 0.050, Steps: 1000, Time: 2.68s
# Episode 1261: Total Reward: 201.628, Epsilon: 0.050, Steps: 487, Time: 1.19s
# Episode 1271: Total Reward: -60.879, Epsilon: 0.050, Steps: 1000, Time: 2.39s
# Episode 1281: Total Reward: 111.174, Epsilon: 0.050, Steps: 794, Time: 1.91s
# Episode 1291: Total Reward: 216.302, Epsilon: 0.050, Steps: 337, Time: 0.74s
# Episode 1301: Total Reward: 240.967, Epsilon: 0.050, Steps: 326, Time: 0.72s
# Checkpoint Reached!
# Episode 1311: Total Reward: 156.239, Epsilon: 0.050, Steps: 657, Time: 1.59s
# Episode 1321: Total Reward: 283.196, Epsilon: 0.050, Steps: 277, Time: 0.62s
# Episode 1331: Total Reward: 144.820, Epsilon: 0.050, Steps: 1000, Time: 2.51s
# Episode 1341: Total Reward: 216.560, Epsilon: 0.050, Steps: 590, Time: 1.52s
# Episode 1351: Total Reward: 285.044, Epsilon: 0.050, Steps: 262, Time: 0.61s
# Episode 1361: Total Reward: -9.024, Epsilon: 0.050, Steps: 1000, Time: 2.23s
# Episode 1371: Total Reward: 123.107, Epsilon: 0.050, Steps: 629, Time: 1.40s
# Episode 1381: Total Reward: -29.159, Epsilon: 0.050, Steps: 421, Time: 0.96s
# Episode 1391: Total Reward: 228.175, Epsilon: 0.050, Steps: 533, Time: 1.40s
# Episode 1401: Total Reward: -2.378, Epsilon: 0.050, Steps: 1000, Time: 2.54s
# Checkpoint Reached!
# Episode 1411: Total Reward: 314.130, Epsilon: 0.050, Steps: 273, Time: 0.63s
# Episode 1421: Total Reward: 206.325, Epsilon: 0.050, Steps: 403, Time: 0.95s
# Episode 1431: Total Reward: 18.782, Epsilon: 0.050, Steps: 1000, Time: 2.24s
# Episode 1441: Total Reward: 215.396, Epsilon: 0.050, Steps: 496, Time: 1.12s
# Episode 1451: Total Reward: 201.088, Epsilon: 0.050, Steps: 372, Time: 0.80s
# Episode 1461: Total Reward: 217.701, Epsilon: 0.050, Steps: 350, Time: 0.81s
# Episode 1471: Total Reward: 224.648, Epsilon: 0.050, Steps: 305, Time: 0.73s
# Episode 1481: Total Reward: 264.305, Epsilon: 0.050, Steps: 342, Time: 0.80s
# Episode 1491: Total Reward: 23.073, Epsilon: 0.050, Steps: 204, Time: 0.49s
# Episode 1501: Total Reward: -51.385, Epsilon: 0.050, Steps: 279, Time: 0.63s
# Checkpoint Reached!
# Episode 1511: Total Reward: 258.866, Epsilon: 0.050, Steps: 314, Time: 0.70s
# Episode 1521: Total Reward: 24.408, Epsilon: 0.050, Steps: 143, Time: 0.33s
# Episode 1531: Total Reward: 265.549, Epsilon: 0.050, Steps: 239, Time: 0.57s
# Episode 1541: Total Reward: 279.379, Epsilon: 0.050, Steps: 240, Time: 0.49s
# Episode 1551: Total Reward: 254.228, Epsilon: 0.050, Steps: 228, Time: 0.36s
# Episode 1561: Total Reward: 246.980, Epsilon: 0.050, Steps: 273, Time: 0.46s
# Episode 1571: Total Reward: 217.608, Epsilon: 0.050, Steps: 287, Time: 0.57s
# Episode 1581: Total Reward: 265.444, Epsilon: 0.050, Steps: 251, Time: 0.44s
# Episode 1591: Total Reward: 242.536, Epsilon: 0.050, Steps: 410, Time: 0.74s
# Episode 1601: Total Reward: -94.622, Epsilon: 0.050, Steps: 587, Time: 1.11s
# Checkpoint Reached!
# Episode 1611: Total Reward: 293.414, Epsilon: 0.050, Steps: 294, Time: 0.52s
# Episode 1621: Total Reward: 179.682, Epsilon: 0.050, Steps: 638, Time: 1.14s
# Episode 1631: Total Reward: 43.498, Epsilon: 0.050, Steps: 1000, Time: 1.71s
# Episode 1641: Total Reward: 244.255, Epsilon: 0.050, Steps: 436, Time: 0.77s
# Episode 1651: Total Reward: 285.998, Epsilon: 0.050, Steps: 177, Time: 0.29s
# Episode 1661: Total Reward: 62.982, Epsilon: 0.050, Steps: 98, Time: 0.16s
# Episode 1671: Total Reward: 276.770, Epsilon: 0.050, Steps: 350, Time: 0.67s
# Episode 1681: Total Reward: 219.965, Epsilon: 0.050, Steps: 271, Time: 0.51s
# Episode 1691: Total Reward: 267.488, Epsilon: 0.050, Steps: 351, Time: 0.67s
# Episode 1701: Total Reward: 219.811, Epsilon: 0.050, Steps: 526, Time: 0.97s
# Checkpoint Reached!
# Episode 1711: Total Reward: 158.863, Epsilon: 0.050, Steps: 447, Time: 0.92s
# Episode 1721: Total Reward: 216.175, Epsilon: 0.050, Steps: 440, Time: 0.74s
# Episode 1731: Total Reward: 20.646, Epsilon: 0.050, Steps: 126, Time: 0.22s
# Episode 1741: Total Reward: 274.090, Epsilon: 0.050, Steps: 398, Time: 0.67s
# Episode 1751: Total Reward: 12.274, Epsilon: 0.050, Steps: 171, Time: 0.30s
# Episode 1761: Total Reward: 236.691, Epsilon: 0.050, Steps: 338, Time: 0.57s
# Episode 1771: Total Reward: 220.996, Epsilon: 0.050, Steps: 311, Time: 0.56s
# Episode 1781: Total Reward: 149.022, Epsilon: 0.050, Steps: 845, Time: 1.41s
# Episode 1791: Total Reward: 24.134, Epsilon: 0.050, Steps: 257, Time: 0.42s
# Episode 1801: Total Reward: 245.920, Epsilon: 0.050, Steps: 315, Time: 0.55s
# Checkpoint Reached!
# Episode 1811: Total Reward: 168.191, Epsilon: 0.050, Steps: 405, Time: 0.66s
# Episode 1821: Total Reward: 258.208, Epsilon: 0.050, Steps: 271, Time: 0.49s
# Episode 1831: Total Reward: 234.119, Epsilon: 0.050, Steps: 343, Time: 0.59s
# Episode 1841: Total Reward: 220.399, Epsilon: 0.050, Steps: 348, Time: 0.61s
# Episode 1851: Total Reward: 250.708, Epsilon: 0.050, Steps: 222, Time: 0.44s
# Episode 1861: Total Reward: 245.971, Epsilon: 0.050, Steps: 274, Time: 0.53s
# Episode 1871: Total Reward: 241.951, Epsilon: 0.050, Steps: 266, Time: 0.46s
# Episode 1881: Total Reward: 250.723, Epsilon: 0.050, Steps: 254, Time: 0.42s
# Episode 1891: Total Reward: 225.590, Epsilon: 0.050, Steps: 347, Time: 0.66s
# Episode 1901: Total Reward: 286.782, Epsilon: 0.050, Steps: 418, Time: 0.80s
# Checkpoint Reached!
# Episode 1911: Total Reward: 228.386, Epsilon: 0.050, Steps: 290, Time: 0.55s
# Episode 1921: Total Reward: 220.489, Epsilon: 0.050, Steps: 256, Time: 0.46s
# Episode 1931: Total Reward: 272.443, Epsilon: 0.050, Steps: 288, Time: 0.56s
# Episode 1941: Total Reward: 265.055, Epsilon: 0.050, Steps: 237, Time: 0.39s
# Episode 1951: Total Reward: 267.408, Epsilon: 0.050, Steps: 241, Time: 0.47s
# Episode 1961: Total Reward: 273.397, Epsilon: 0.050, Steps: 244, Time: 0.53s
# Episode 1971: Total Reward: 256.799, Epsilon: 0.050, Steps: 206, Time: 0.33s
# Episode 1981: Total Reward: 249.688, Epsilon: 0.050, Steps: 229, Time: 0.46s
# Episode 1991: Total Reward: 236.538, Epsilon: 0.050, Steps: 217, Time: 0.37s

# %% [markdown]
# ## Training Results

# %%
results = torch.load("dqn_lunar_lander_v3_checkpoint.pth", weights_only=False)

rewards_per_episode = results["rewards_per_episode"]
epsilon_values = results["epsilon_values"]
steps_per_episode = results["steps_per_episode"]

plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(epsilon_values)
plt.title("Epsilon Values - Training")
plt.xlabel("Episode")
plt.ylabel("Epsilon")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## LunarLander-v3 - Evaluation

# %%
steps_arr = []
rewards_arr = []

env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

state_dim = lunar_env.observation_space.shape[0]
action_dim = lunar_env.action_space.n

trained_agent = DQNAgent(state_dim, action_dim)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_agent.policy_net.load_state_dict(torch.load("dqn_lunar_lander_v3.pth", map_location=device, weights_only=True))

for episode in range(10):
    obs, _ = lunar_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action = trained_agent.select_greedy_action(state)
        obs, reward, done, truncated, _ = lunar_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = 264.89155258802, Steps taken: 197
# Episode 2: Total Reward = 122.45566427332697, Steps taken: 1000
# Episode 3: Total Reward = 297.65268022130874, Steps taken: 166
# Episode 4: Total Reward = 272.60621779230473, Steps taken: 208
# Episode 5: Total Reward = 306.5185616023056, Steps taken: 381
# Episode 6: Total Reward = 271.90556568675333, Steps taken: 178
# Episode 7: Total Reward = 255.36943664190017, Steps taken: 217
# Episode 8: Total Reward = 277.4955345753777, Steps taken: 221
# Episode 9: Total Reward = 255.88433247771678, Steps taken: 233
# Episode 10: Total Reward = 251.75050700145493, Steps taken: 187
#
# Average reward over 10 episodes: 257.6530052860469
# Average steps taken over 10 episodes: 298.8
