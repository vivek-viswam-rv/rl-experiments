# %% [markdown]
# # Lunar Lander - DDQN

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Agent-related Class Definitions

# %%
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DQNAgent:
    BATCH_SIZE = 32
    EPSILON_START = 1
    EPSILON_CUTOFF = 0.05
    EPSILON_DECAY = 100000
    GAMMA = 0.99
    LR = 1e-4
    MEMORY_SIZE = 10000
    total_steps = 0

    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net = DQN(state_dim, action_dim).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = ReplayBuffer(self.MEMORY_SIZE)
        self.steps_done = 0
        self.epsilon = self.EPSILON_START

    def select_e_greedy_action(self, env, state):
        if random.random() < self.epsilon:
            return random.randint(0, env.action_space.n - 1)
        else:
            state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state).argmax(dim=1).item()

    def select_greedy_action(self, state):
      state = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
      with torch.no_grad():
          return self.policy_net(state).argmax(dim=1).item()

    def decay_epsilon(self):
      self.total_steps += 1
      self.epsilon = max(self.EPSILON_CUTOFF, self.EPSILON_START - (self.total_steps / self.EPSILON_DECAY))

    def train(self):
        if len(self.memory) < self.BATCH_SIZE:
            return
        batch = self.memory.sample(self.BATCH_SIZE)

        states, actions, rewards, next_states, dones = zip(*batch)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(np.array(actions), dtype=torch.int64, device=self.device).unsqueeze(1)
        rewards = torch.tensor(np.array(rewards), dtype=torch.float32, device=self.device).unsqueeze(1)
        next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=self.device)
        dones = torch.tensor(np.array(dones), dtype=torch.float32, device=self.device).unsqueeze(1)
        current_q = self.policy_net(states).gather(1, actions)
        next_q = self.target_net(next_states).max(1, keepdim=True)[0].detach()
        target_q = rewards + (self.GAMMA * next_q * (1 - dones))

        loss = F.mse_loss(target_q, current_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

class DoubleDQNAgent(DQNAgent):
  EPSILON_DECAY = 1000
  TARGET_UPDATE_RATE = 0.05

  def train(self):
    if len(self.memory) < self.BATCH_SIZE:
        return
    batch = self.memory.sample(self.BATCH_SIZE)

    states, actions, rewards, next_states, dones = zip(*batch)
    states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
    actions = torch.tensor(np.array(actions), dtype=torch.int64, device=self.device).unsqueeze(1)
    rewards = torch.tensor(np.array(rewards), dtype=torch.float32, device=self.device).unsqueeze(1)
    next_states = torch.tensor(np.array(next_states), dtype=torch.float32, device=self.device)
    dones = torch.tensor(np.array(dones), dtype=torch.float32, device=self.device).unsqueeze(1)

    with torch.no_grad():
      policy_best_actions = self.policy_net(next_states).argmax(1, keepdim=True)
      next_q = self.target_net(next_states).gather(1, policy_best_actions)
      target_q = rewards + self.GAMMA * next_q * (1 - dones)

    current_q = self.policy_net(states).gather(1, actions)

    loss = F.mse_loss(target_q, current_q)
    self.optimizer.zero_grad()
    loss.backward()
    self.optimizer.step()

  def update_target_network(self):
    for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
      new_params = self.TARGET_UPDATE_RATE * policy_param.data + (1.0 - self.TARGET_UPDATE_RATE) * target_param.data
      target_param.data.copy_(new_params)

# %% [markdown]
# ## Training Function Definition

# %%
def train_q_values_ddqn(env, env_name,target_update_interval = 10, training_episodes = 1000, agent_class = DoubleDQNAgent):
  MAX_STEPS = 1000
  CONVERGENCE_REWARD_COUNT = 20
  CONVERGENCE_MIN_REWARD = 270

  state_dim = env.observation_space.shape[0]
  action_dim = env.action_space.n
  agent = agent_class(state_dim, action_dim)
  rewards_per_episode = []
  episode_times = []
  steps_per_episode = []
  epsilon_values = []

  for episode in range(training_episodes):
    start_time = time.time()
    obs, _ = env.reset()
    state = obs
    total_reward = 0
    done = False
    steps_taken = 0
    episode_transitions = []

    epsilon_values.append(agent.epsilon)

    while not done and steps_taken < MAX_STEPS:
        action = agent.select_e_greedy_action(env, state)
        obs, reward, done, _, _ = env.step(action)
        next_state = np.array(obs, dtype=np.float32)
        episode_transitions.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        steps_taken += 1

        agent.decay_epsilon()

    average_rewards_over_last_episodes = np.mean(rewards_per_episode[-CONVERGENCE_REWARD_COUNT:])
      
    if average_rewards_over_last_episodes >= CONVERGENCE_MIN_REWARD and total_reward >= CONVERGENCE_MIN_REWARD:
        print("Early stopping condition met! Stopping training.")
        print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        break
    
    for transition in episode_transitions:
        agent.memory.push(*transition)
        agent.update_target_network()

    for _ in range(len(episode_transitions)):
        agent.train()

    end_time = time.time()
    episode_time = end_time - start_time
    episode_times.append(episode_time)
    rewards_per_episode.append(total_reward)
    steps_per_episode.append(steps_taken)

    if episode % 10 == 0:
      print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Epsilon: {agent.epsilon:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")

    if episode % 100 == 0:
      checkpoint = {
        'policy_net_state_dict': agent.policy_net.state_dict(),
        'optimizer_state_dict': agent.optimizer.state_dict(),
        'total_steps': agent.total_steps,
        'rewards_per_episode': rewards_per_episode,
        'epsilon_values': epsilon_values,
        'episode_times': episode_times,
        'steps_per_episode': steps_per_episode
      }

      torch.save(checkpoint, "ddqn_lunar_lander_v3_checkpoint.pth")
      torch.save(agent.policy_net.state_dict(), "ddqn_lunar_lander_v3.pth")
      print("Checkpoint Reached!")

  return agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode

# %% [markdown]
# ## LunarLander-v3 - Training

# %%
env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

trained_agent, rewards_per_episode, epsilon_values, episode_times, steps_per_episode = train_q_values_ddqn(lunar_env, env_name, training_episodes = 3000)

checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'total_steps': trained_agent.total_steps,
    'rewards_per_episode': rewards_per_episode,
    'epsilon_values': epsilon_values,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}

torch.save(checkpoint, "ddqn_lunar_lander_v3_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "ddqn_lunar_lander_v3.pth")
# Out:
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 1: Total Reward: -110.141, Epsilon: 0.923, Steps: 77, Time: 0.27s
# Checkpoint Reached!
# Episode 11: Total Reward: -339.536, Epsilon: 0.050, Steps: 68, Time: 0.25s
# Episode 21: Total Reward: -172.536, Epsilon: 0.050, Steps: 1000, Time: 3.95s
# Episode 31: Total Reward: -305.409, Epsilon: 0.050, Steps: 146, Time: 0.55s
# Episode 41: Total Reward: -124.487, Epsilon: 0.050, Steps: 1000, Time: 3.89s
# Episode 51: Total Reward: -83.184, Epsilon: 0.050, Steps: 1000, Time: 2.90s
# Episode 61: Total Reward: -132.143, Epsilon: 0.050, Steps: 1000, Time: 2.95s
# Episode 71: Total Reward: -55.548, Epsilon: 0.050, Steps: 1000, Time: 2.98s
# Episode 81: Total Reward: -140.509, Epsilon: 0.050, Steps: 701, Time: 2.04s
# Episode 91: Total Reward: -113.810, Epsilon: 0.050, Steps: 1000, Time: 2.95s
# Episode 101: Total Reward: -104.206, Epsilon: 0.050, Steps: 1000, Time: 2.87s
# Checkpoint Reached!
# Episode 111: Total Reward: -141.870, Epsilon: 0.050, Steps: 188, Time: 0.58s
# Episode 121: Total Reward: -303.254, Epsilon: 0.050, Steps: 652, Time: 1.94s
# Episode 131: Total Reward: -136.187, Epsilon: 0.050, Steps: 193, Time: 0.55s
# Episode 141: Total Reward: -125.645, Epsilon: 0.050, Steps: 1000, Time: 3.18s
# Episode 151: Total Reward: -37.621, Epsilon: 0.050, Steps: 1000, Time: 2.99s
# Episode 161: Total Reward: -26.741, Epsilon: 0.050, Steps: 1000, Time: 2.91s
# Episode 171: Total Reward: -54.856, Epsilon: 0.050, Steps: 1000, Time: 3.14s
# Episode 181: Total Reward: -25.497, Epsilon: 0.050, Steps: 1000, Time: 2.82s
# Episode 191: Total Reward: -37.896, Epsilon: 0.050, Steps: 1000, Time: 2.84s
# Episode 201: Total Reward: -24.317, Epsilon: 0.050, Steps: 1000, Time: 2.96s
# Checkpoint Reached!
# Episode 211: Total Reward: 6.752, Epsilon: 0.050, Steps: 1000, Time: 3.05s
# Episode 221: Total Reward: -35.543, Epsilon: 0.050, Steps: 1000, Time: 2.78s
# Episode 231: Total Reward: -21.153, Epsilon: 0.050, Steps: 1000, Time: 2.83s
# Episode 241: Total Reward: -4.935, Epsilon: 0.050, Steps: 1000, Time: 2.81s
# Episode 251: Total Reward: -11.852, Epsilon: 0.050, Steps: 1000, Time: 2.85s
# Episode 261: Total Reward: 211.916, Epsilon: 0.050, Steps: 406, Time: 1.02s
# Episode 271: Total Reward: -179.500, Epsilon: 0.050, Steps: 831, Time: 2.97s
# Episode 281: Total Reward: -63.536, Epsilon: 0.050, Steps: 1000, Time: 2.94s
# Episode 291: Total Reward: 113.443, Epsilon: 0.050, Steps: 550, Time: 1.73s
# Episode 301: Total Reward: 230.745, Epsilon: 0.050, Steps: 305, Time: 0.87s
# Checkpoint Reached!
# Episode 311: Total Reward: -82.325, Epsilon: 0.050, Steps: 308, Time: 0.99s
# Episode 321: Total Reward: 218.237, Epsilon: 0.050, Steps: 289, Time: 0.84s
# Episode 331: Total Reward: 194.560, Epsilon: 0.050, Steps: 429, Time: 1.25s
# Episode 341: Total Reward: 291.231, Epsilon: 0.050, Steps: 246, Time: 0.72s
# Episode 351: Total Reward: 263.783, Epsilon: 0.050, Steps: 252, Time: 0.80s
# Episode 361: Total Reward: 187.524, Epsilon: 0.050, Steps: 342, Time: 0.97s
# Episode 371: Total Reward: 250.372, Epsilon: 0.050, Steps: 264, Time: 0.83s
# Episode 381: Total Reward: -88.452, Epsilon: 0.050, Steps: 1000, Time: 2.93s
# Episode 391: Total Reward: -36.331, Epsilon: 0.050, Steps: 1000, Time: 3.02s
# Episode 401: Total Reward: 239.711, Epsilon: 0.050, Steps: 259, Time: 0.76s
# Checkpoint Reached!
# Episode 411: Total Reward: 61.190, Epsilon: 0.050, Steps: 181, Time: 0.55s
# Episode 421: Total Reward: 270.939, Epsilon: 0.050, Steps: 206, Time: 0.69s
# Episode 431: Total Reward: 17.619, Epsilon: 0.050, Steps: 1000, Time: 3.02s
# Episode 441: Total Reward: -91.877, Epsilon: 0.050, Steps: 292, Time: 1.12s
# Episode 451: Total Reward: -19.888, Epsilon: 0.050, Steps: 1000, Time: 2.93s
# Episode 461: Total Reward: -137.308, Epsilon: 0.050, Steps: 782, Time: 2.24s
# Episode 471: Total Reward: 65.941, Epsilon: 0.050, Steps: 1000, Time: 2.82s
# Episode 481: Total Reward: -8.145, Epsilon: 0.050, Steps: 298, Time: 0.84s
# Episode 491: Total Reward: 177.169, Epsilon: 0.050, Steps: 538, Time: 1.55s
# Episode 501: Total Reward: -52.916, Epsilon: 0.050, Steps: 1000, Time: 2.86s
# Checkpoint Reached!
# Episode 511: Total Reward: 142.259, Epsilon: 0.050, Steps: 470, Time: 1.49s
# Episode 521: Total Reward: 172.916, Epsilon: 0.050, Steps: 509, Time: 1.79s
# Episode 531: Total Reward: -60.890, Epsilon: 0.050, Steps: 1000, Time: 2.70s
# Episode 541: Total Reward: 198.943, Epsilon: 0.050, Steps: 648, Time: 2.01s
# Episode 551: Total Reward: 238.699, Epsilon: 0.050, Steps: 466, Time: 1.54s
# Episode 561: Total Reward: 66.319, Epsilon: 0.050, Steps: 1000, Time: 3.86s
# Episode 571: Total Reward: 195.476, Epsilon: 0.050, Steps: 364, Time: 1.07s
# Episode 581: Total Reward: 253.571, Epsilon: 0.050, Steps: 462, Time: 1.45s
# Episode 591: Total Reward: 119.262, Epsilon: 0.050, Steps: 1000, Time: 2.76s
# Episode 601: Total Reward: 184.466, Epsilon: 0.050, Steps: 621, Time: 1.79s
# Checkpoint Reached!
# Episode 611: Total Reward: 207.233, Epsilon: 0.050, Steps: 371, Time: 1.10s
# Episode 621: Total Reward: 136.652, Epsilon: 0.050, Steps: 1000, Time: 2.85s
# Episode 631: Total Reward: 260.765, Epsilon: 0.050, Steps: 287, Time: 0.82s
# Episode 641: Total Reward: 263.811, Epsilon: 0.050, Steps: 293, Time: 0.80s
# Episode 651: Total Reward: 266.757, Epsilon: 0.050, Steps: 248, Time: 0.72s
# Episode 661: Total Reward: 246.498, Epsilon: 0.050, Steps: 294, Time: 0.81s
# Episode 671: Total Reward: 250.029, Epsilon: 0.050, Steps: 284, Time: 0.84s
# Episode 681: Total Reward: 221.301, Epsilon: 0.050, Steps: 844, Time: 2.41s
# Episode 691: Total Reward: 260.706, Epsilon: 0.050, Steps: 238, Time: 0.65s
# Episode 701: Total Reward: 271.643, Epsilon: 0.050, Steps: 227, Time: 0.92s
# Checkpoint Reached!
# Episode 711: Total Reward: 272.813, Epsilon: 0.050, Steps: 222, Time: 0.67s
# Episode 721: Total Reward: 196.385, Epsilon: 0.050, Steps: 328, Time: 0.97s
# Episode 731: Total Reward: 242.913, Epsilon: 0.050, Steps: 251, Time: 0.75s
# Episode 741: Total Reward: 301.022, Epsilon: 0.050, Steps: 234, Time: 0.71s
# Episode 751: Total Reward: 226.882, Epsilon: 0.050, Steps: 376, Time: 1.06s
# Episode 761: Total Reward: 235.896, Epsilon: 0.050, Steps: 254, Time: 0.74s
# Episode 771: Total Reward: 118.085, Epsilon: 0.050, Steps: 1000, Time: 2.93s
# Episode 781: Total Reward: 261.277, Epsilon: 0.050, Steps: 332, Time: 1.00s
# Episode 791: Total Reward: 214.573, Epsilon: 0.050, Steps: 274, Time: 0.80s
# Episode 801: Total Reward: 100.149, Epsilon: 0.050, Steps: 1000, Time: 2.94s
# Checkpoint Reached!
# Episode 811: Total Reward: 225.785, Epsilon: 0.050, Steps: 244, Time: 0.77s
# Episode 821: Total Reward: 266.710, Epsilon: 0.050, Steps: 821, Time: 2.39s
# Episode 831: Total Reward: 225.633, Epsilon: 0.050, Steps: 277, Time: 0.84s
# Episode 841: Total Reward: 9.462, Epsilon: 0.050, Steps: 162, Time: 0.45s
# Episode 851: Total Reward: 229.685, Epsilon: 0.050, Steps: 261, Time: 0.78s
# Episode 861: Total Reward: 6.618, Epsilon: 0.050, Steps: 1000, Time: 2.88s
# Episode 871: Total Reward: 34.643, Epsilon: 0.050, Steps: 1000, Time: 3.03s
# Episode 881: Total Reward: 228.075, Epsilon: 0.050, Steps: 899, Time: 2.63s
# Episode 891: Total Reward: 231.205, Epsilon: 0.050, Steps: 482, Time: 1.61s
# Episode 901: Total Reward: 107.752, Epsilon: 0.050, Steps: 1000, Time: 2.95s
# Checkpoint Reached!
# Episode 911: Total Reward: 225.381, Epsilon: 0.050, Steps: 215, Time: 0.68s
# Episode 921: Total Reward: 249.035, Epsilon: 0.050, Steps: 263, Time: 0.80s
# Episode 931: Total Reward: 289.555, Epsilon: 0.050, Steps: 344, Time: 1.07s
# Episode 941: Total Reward: 236.217, Epsilon: 0.050, Steps: 240, Time: 0.75s
# Episode 951: Total Reward: 230.128, Epsilon: 0.050, Steps: 304, Time: 0.87s
# Episode 961: Total Reward: 211.831, Epsilon: 0.050, Steps: 362, Time: 1.06s
# Episode 971: Total Reward: 226.298, Epsilon: 0.050, Steps: 387, Time: 1.18s
# Episode 981: Total Reward: 226.819, Epsilon: 0.050, Steps: 421, Time: 1.27s
# Episode 991: Total Reward: 232.601, Epsilon: 0.050, Steps: 996, Time: 2.95s
# Episode 1001: Total Reward: 233.601, Epsilon: 0.050, Steps: 278, Time: 0.80s
# Checkpoint Reached!
# Episode 1011: Total Reward: 218.319, Epsilon: 0.050, Steps: 307, Time: 0.92s
# Episode 1021: Total Reward: 258.734, Epsilon: 0.050, Steps: 401, Time: 1.13s
# Episode 1031: Total Reward: 277.190, Epsilon: 0.050, Steps: 227, Time: 0.67s
# Episode 1041: Total Reward: 230.401, Epsilon: 0.050, Steps: 308, Time: 0.91s
# Episode 1051: Total Reward: 17.684, Epsilon: 0.050, Steps: 1000, Time: 2.86s
# Episode 1061: Total Reward: 214.170, Epsilon: 0.050, Steps: 372, Time: 1.08s
# Episode 1071: Total Reward: 217.333, Epsilon: 0.050, Steps: 372, Time: 1.05s
# Episode 1081: Total Reward: 218.981, Epsilon: 0.050, Steps: 499, Time: 1.54s
# Episode 1091: Total Reward: 252.399, Epsilon: 0.050, Steps: 344, Time: 1.07s
# Episode 1101: Total Reward: 285.717, Epsilon: 0.050, Steps: 248, Time: 0.79s
# Checkpoint Reached!
# Episode 1111: Total Reward: 285.295, Epsilon: 0.050, Steps: 308, Time: 1.06s
# Episode 1121: Total Reward: 231.521, Epsilon: 0.050, Steps: 469, Time: 1.27s
# Episode 1131: Total Reward: 247.923, Epsilon: 0.050, Steps: 363, Time: 0.99s
# Episode 1141: Total Reward: 241.233, Epsilon: 0.050, Steps: 256, Time: 0.65s
# Episode 1151: Total Reward: 216.782, Epsilon: 0.050, Steps: 856, Time: 2.26s
# Episode 1161: Total Reward: 217.712, Epsilon: 0.050, Steps: 433, Time: 1.35s
# Episode 1171: Total Reward: 255.594, Epsilon: 0.050, Steps: 373, Time: 1.03s
# Episode 1181: Total Reward: 255.214, Epsilon: 0.050, Steps: 335, Time: 0.93s
# Episode 1191: Total Reward: 259.758, Epsilon: 0.050, Steps: 859, Time: 2.36s
# Episode 1201: Total Reward: 145.830, Epsilon: 0.050, Steps: 1000, Time: 2.82s
# Checkpoint Reached!
# Episode 1211: Total Reward: 283.879, Epsilon: 0.050, Steps: 230, Time: 0.61s
# Episode 1221: Total Reward: 232.306, Epsilon: 0.050, Steps: 204, Time: 0.55s
# Episode 1231: Total Reward: 256.345, Epsilon: 0.050, Steps: 234, Time: 0.62s
# Episode 1241: Total Reward: 259.577, Epsilon: 0.050, Steps: 278, Time: 0.79s
# Episode 1251: Total Reward: -53.104, Epsilon: 0.050, Steps: 147, Time: 0.39s
# Episode 1261: Total Reward: 275.674, Epsilon: 0.050, Steps: 286, Time: 0.75s
# Episode 1271: Total Reward: 268.823, Epsilon: 0.050, Steps: 223, Time: 0.62s
# Episode 1281: Total Reward: 295.370, Epsilon: 0.050, Steps: 431, Time: 1.20s
# Episode 1291: Total Reward: -28.915, Epsilon: 0.050, Steps: 115, Time: 0.36s
# Episode 1301: Total Reward: 273.802, Epsilon: 0.050, Steps: 272, Time: 0.85s
# Checkpoint Reached!
# Episode 1311: Total Reward: 255.145, Epsilon: 0.050, Steps: 266, Time: 0.73s
# Episode 1321: Total Reward: 229.912, Epsilon: 0.050, Steps: 181, Time: 0.48s
# Episode 1331: Total Reward: 232.621, Epsilon: 0.050, Steps: 257, Time: 0.74s
# Episode 1341: Total Reward: 240.610, Epsilon: 0.050, Steps: 321, Time: 0.85s
# Episode 1351: Total Reward: 284.062, Epsilon: 0.050, Steps: 318, Time: 0.90s
# Episode 1361: Total Reward: 231.417, Epsilon: 0.050, Steps: 289, Time: 0.84s
# Episode 1371: Total Reward: 165.237, Epsilon: 0.050, Steps: 1000, Time: 3.10s
# Episode 1381: Total Reward: 242.330, Epsilon: 0.050, Steps: 272, Time: 0.73s
# Episode 1391: Total Reward: 273.878, Epsilon: 0.050, Steps: 309, Time: 0.92s
# Episode 1401: Total Reward: 302.158, Epsilon: 0.050, Steps: 229, Time: 0.62s
# Checkpoint Reached!
# Episode 1411: Total Reward: 257.251, Epsilon: 0.050, Steps: 367, Time: 1.07s
# Episode 1421: Total Reward: 284.964, Epsilon: 0.050, Steps: 243, Time: 0.67s
# Episode 1431: Total Reward: 264.564, Epsilon: 0.050, Steps: 327, Time: 0.96s
# Episode 1441: Total Reward: 256.010, Epsilon: 0.050, Steps: 254, Time: 0.70s
# Episode 1451: Total Reward: 256.702, Epsilon: 0.050, Steps: 279, Time: 0.83s
# Episode 1461: Total Reward: 221.828, Epsilon: 0.050, Steps: 271, Time: 0.89s
# Episode 1471: Total Reward: 230.593, Epsilon: 0.050, Steps: 235, Time: 0.68s
# Episode 1481: Total Reward: 248.835, Epsilon: 0.050, Steps: 650, Time: 1.92s
# Episode 1491: Total Reward: 172.913, Epsilon: 0.050, Steps: 361, Time: 0.96s
# Episode 1501: Total Reward: 176.026, Epsilon: 0.050, Steps: 273, Time: 0.70s
# Checkpoint Reached!
# Episode 1511: Total Reward: 258.246, Epsilon: 0.050, Steps: 268, Time: 0.81s
# Episode 1521: Total Reward: 251.353, Epsilon: 0.050, Steps: 237, Time: 0.75s
# Episode 1531: Total Reward: 246.833, Epsilon: 0.050, Steps: 319, Time: 0.88s
# Episode 1541: Total Reward: 286.855, Epsilon: 0.050, Steps: 266, Time: 0.74s
# Episode 1551: Total Reward: 231.540, Epsilon: 0.050, Steps: 229, Time: 0.70s
# Episode 1561: Total Reward: 252.035, Epsilon: 0.050, Steps: 226, Time: 0.73s
# Episode 1571: Total Reward: 237.316, Epsilon: 0.050, Steps: 213, Time: 0.60s
# Episode 1581: Total Reward: 240.119, Epsilon: 0.050, Steps: 223, Time: 0.66s
# Episode 1591: Total Reward: 295.888, Epsilon: 0.050, Steps: 207, Time: 0.55s
# Episode 1601: Total Reward: 245.870, Epsilon: 0.050, Steps: 239, Time: 0.63s
# Checkpoint Reached!
# Episode 1611: Total Reward: 272.985, Epsilon: 0.050, Steps: 242, Time: 0.65s
# Episode 1621: Total Reward: 265.394, Epsilon: 0.050, Steps: 200, Time: 0.57s
# Early stopping condition met! Stopping training.
# Episode 1628: Total Reward: 277.107, Epsilon: 0.050, Steps: 224, Time: 0.62s

# %% [markdown]
# ## Training Results

# %%
results = torch.load("ddqn_lunar_lander_v3_checkpoint.pth", weights_only=False)

rewards_per_episode = results["rewards_per_episode"]
epsilon_values = results["epsilon_values"]
steps_per_episode = results["steps_per_episode"]

plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(epsilon_values)
plt.title("Epsilon Values - Training")
plt.xlabel("Episode")
plt.ylabel("Epsilon")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## LunarLander-v3 - Evaluation

# %%
steps_arr = []
rewards_arr = []

env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

state_dim = lunar_env.observation_space.shape[0]
action_dim = lunar_env.action_space.n

trained_agent = DoubleDQNAgent(state_dim, action_dim)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_agent.policy_net.load_state_dict(torch.load("ddqn_lunar_lander_v3.pth", map_location=device, weights_only=True))

for episode in range(10):
    obs, _ = lunar_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action = trained_agent.select_greedy_action(state)
        obs, reward, done, truncated, _ = lunar_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = 285.2812093862583, Steps taken: 189
# Episode 2: Total Reward = 281.43731023131863, Steps taken: 248
# Episode 3: Total Reward = 260.6457397352215, Steps taken: 198
# Episode 4: Total Reward = 245.64328075259144, Steps taken: 237
# Episode 5: Total Reward = 219.91291561631073, Steps taken: 221
# Episode 6: Total Reward = 239.8932603261272, Steps taken: 198
# Episode 7: Total Reward = 285.34803840556947, Steps taken: 229
# Episode 8: Total Reward = 111.72891903608463, Steps taken: 1000
# Episode 9: Total Reward = 278.19632216488276, Steps taken: 264
# Episode 10: Total Reward = 273.7432537579102, Steps taken: 225
#
# Average reward over 10 episodes: 248.1830249412275
# Average steps taken over 10 episodes: 300.9
