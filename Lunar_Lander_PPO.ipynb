# %% [markdown]
# # Lunar Lander - PPO

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque, namedtuple

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Agent-related Class Definitions

# %%
class PPONet(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PPONet, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )
        self.actor = nn.Linear(128, action_dim)
        self.critic = nn.Linear(128, 1)

    def forward(self, x):
        x = self.shared(x)
        logits = self.actor(x)
        value = self.critic(x)
        return logits, value

class PPOAgent:
    BATCH_SIZE = 32
    CLIP_PARAM = 0.2
    GAMMA = 0.99
    LR = 1e-4
    GAE_LAMBDA = 0.95
    PPO_EPOCHS = 10
    VALUE_LOSS_COEF = 0.5
    ENTROPY_COEF = 0.01

    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = PPONet(state_dim, action_dim).to(self.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = []
        self.clip = self.CLIP_PARAM

    def store_transition(self, state, action, reward, next_state, done, log_prob, value):
        self.memory.append((state, action, reward, next_state, done, log_prob, value))

    def select_action(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
        logits, value = self.policy_net(state_tensor)
        probs = F.softmax(logits, dim=-1)
        log_probs = F.log_softmax(logits, dim=-1)
        action = torch.multinomial(probs, 1).item()
        log_prob = log_probs[0, action].item()
        
        return action, log_prob, value.item()

    def compute_gae(self, rewards, values, next_value, dones):
        advantages = []
        gae = 0
        values = values + [next_value]
        for t in reversed(range(len(rewards))):
            delta = rewards[t] + self.GAMMA * values[t + 1] * (1 - dones[t]) - values[t]
            gae = delta + self.GAMMA * self.GAE_LAMBDA * (1 - dones[t]) * gae
            advantages.insert(0, gae)
        advantages = torch.tensor(advantages, dtype=torch.float32, device=self.device)
        returns = advantages + torch.tensor(values[:-1], dtype=torch.float32, device=self.device)
        
        return advantages, returns

    def step(self):
        if len(self.memory) < self.BATCH_SIZE:
            return

        states, actions, rewards, next_states, dones, old_log_probs, old_values = zip(*self.memory)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(actions, dtype=torch.int64, device=self.device)
        old_log_probs = torch.tensor(old_log_probs, dtype=torch.float32, device=self.device)
        old_values = torch.tensor(old_values, dtype=torch.float32, device=self.device)

        with torch.no_grad():
            _, next_value = self.policy_net(states[-1:])
        advantages, returns = self.compute_gae(rewards, old_values.tolist(), next_value.item(), dones)
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.PPO_EPOCHS):
            logits, values = self.policy_net(states)
            probs = F.softmax(logits, dim=-1)
            log_probs = F.log_softmax(logits, dim=-1)
            selected_log_probs = log_probs[range(len(actions)), actions]

            ratios = torch.exp(selected_log_probs - old_log_probs)
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1 - self.clip, 1 + self.clip) * advantages
            policy_loss = -torch.min(surr1, surr2).mean()

            value_loss = F.mse_loss(values.squeeze(), returns)
            entropy = -(probs * log_probs).sum(dim=-1).mean()

            loss = policy_loss + self.VALUE_LOSS_COEF * value_loss - self.ENTROPY_COEF * entropy

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        self.memory.clear()

# %% [markdown]
# ## Training Function Definition

# %%
def train_ppo(env, training_episodes=1000, agent_class=PPOAgent):
    CONVERGENCE_REWARD_COUNT = 20
    CONVERGENCE_MIN_REWARD = 270
    
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n
    
    agent = agent_class(state_dim, action_dim)
    rewards_per_episode = []
    steps_per_episode = []
    episode_times = []
    start_episode = 0
    early_stop_counter = 0

    for episode in range(training_episodes):
        start_time = time.time()
        obs, _ = env.reset()
        state = obs
        total_reward = 0
        done = False
        steps_taken = 0
        agent.memory = []

        while not done:
            action, log_prob, value = agent.select_action(state)
            obs, reward, done, _, _ = env.step(action)
            next_state = np.array(obs, dtype=np.float32)
            total_reward += reward
            steps_taken += 1

            agent.store_transition(state, action, reward, next_state, done, log_prob, value)
            state = next_state

        average_rewards_over_last_episodes = np.mean(rewards_per_episode[-CONVERGENCE_REWARD_COUNT:])
          
        if average_rewards_over_last_episodes >= CONVERGENCE_MIN_REWARD and total_reward >= CONVERGENCE_MIN_REWARD:
            print("Early stopping condition met! Stopping training.")
            print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
            break
        
        agent.step()
        steps_per_episode.append(steps_taken)
        rewards_per_episode.append(total_reward)
        episode_time = time.time() - start_time
        episode_times.append(episode_time)

        if episode % 10 == 0:    
            print(f"Episode {episode + 1}: Total Reward: {total_reward}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        if episode % 100 == 0:
            checkpoint = {
              'policy_net_state_dict': agent.policy_net.state_dict(),
              'optimizer_state_dict': agent.optimizer.state_dict(),
              'rewards_per_episode': rewards_per_episode,
              'episode_times': episode_times,
              'steps_per_episode': steps_per_episode
            }

            torch.save(checkpoint, "ppo_lunar_lander_v3_checkpoint.pth")
            torch.save(agent.policy_net.state_dict(), "ppo_lunar_lander_v3.pth")
            print("Checkpoint Reached!")
   
    return agent, rewards_per_episode, episode_times, steps_per_episode

# %% [markdown]
# ## LunarLander-v3 - Training

# %%
env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

trained_agent, rewards_per_episode, episode_times, steps_per_episode = train_ppo(lunar_env, training_episodes = 1500)

checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'rewards_per_episode': rewards_per_episode,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}

torch.save(checkpoint, "ppo_lunar_lander_v3_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "ppo_lunar_lander_v3.pth")
# Out:
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 1: Total Reward: -126.49720174999294, Steps: 77, Time: 0.08s
# Checkpoint Reached!
# Episode 11: Total Reward: -89.07287615965045, Steps: 107, Time: 0.09s
# Episode 21: Total Reward: -142.69321460155874, Steps: 71, Time: 0.07s
# Episode 31: Total Reward: -157.5224058493108, Steps: 108, Time: 0.08s
# Episode 41: Total Reward: -394.64711041437005, Steps: 85, Time: 0.08s
# Episode 51: Total Reward: -549.7562856817914, Steps: 79, Time: 0.07s
# Episode 61: Total Reward: -314.4504359194983, Steps: 86, Time: 0.12s
# Episode 71: Total Reward: -85.03354963969079, Steps: 79, Time: 0.07s
# Episode 81: Total Reward: -89.47505682699477, Steps: 132, Time: 0.10s
# Episode 91: Total Reward: -135.474737695516, Steps: 68, Time: 0.07s
# Episode 101: Total Reward: -166.48394253186905, Steps: 108, Time: 0.10s
# Checkpoint Reached!
# Episode 111: Total Reward: -165.3259004946549, Steps: 80, Time: 0.07s
# Episode 121: Total Reward: -473.4710660821102, Steps: 114, Time: 0.12s
# Episode 131: Total Reward: -105.83180839548777, Steps: 80, Time: 0.06s
# Episode 141: Total Reward: -247.05839993236214, Steps: 99, Time: 0.08s
# Episode 151: Total Reward: -105.97332105139171, Steps: 53, Time: 0.04s
# Episode 161: Total Reward: -424.85254259492194, Steps: 143, Time: 0.08s
# Episode 171: Total Reward: -341.42376084151226, Steps: 119, Time: 0.09s
# Episode 181: Total Reward: -683.0508245566847, Steps: 132, Time: 0.09s
# Episode 191: Total Reward: -404.62038057566645, Steps: 82, Time: 0.06s
# Episode 201: Total Reward: -417.1061421848365, Steps: 87, Time: 0.05s
# Checkpoint Reached!
# Episode 211: Total Reward: -772.4517548720904, Steps: 146, Time: 0.09s
# Episode 221: Total Reward: -57.53926056741446, Steps: 85, Time: 0.08s
# Episode 231: Total Reward: -396.4355749447865, Steps: 80, Time: 0.06s
# Episode 241: Total Reward: -821.6822206298026, Steps: 136, Time: 0.10s
# Episode 251: Total Reward: -685.6987971226566, Steps: 115, Time: 0.08s
# Episode 261: Total Reward: -831.3335404651594, Steps: 139, Time: 0.08s
# Episode 271: Total Reward: -421.89349758574446, Steps: 73, Time: 0.06s
# Episode 281: Total Reward: -639.7485830699557, Steps: 142, Time: 0.08s
# Episode 291: Total Reward: -801.0768179346703, Steps: 186, Time: 0.10s
# Episode 301: Total Reward: -523.9437886095485, Steps: 122, Time: 0.08s
# Checkpoint Reached!
# Episode 311: Total Reward: -461.39203605507373, Steps: 93, Time: 0.06s
# Episode 321: Total Reward: -651.8429525989134, Steps: 143, Time: 0.08s
# Episode 331: Total Reward: -756.5497790884584, Steps: 122, Time: 0.07s
# Episode 341: Total Reward: -553.278757227974, Steps: 80, Time: 0.04s
# Episode 351: Total Reward: -499.77222216227557, Steps: 91, Time: 0.06s
# Episode 361: Total Reward: -733.0783222143779, Steps: 181, Time: 0.09s
# Episode 371: Total Reward: -228.62748491630788, Steps: 106, Time: 0.06s
# Episode 381: Total Reward: -324.8771581254084, Steps: 100, Time: 0.07s
# Episode 391: Total Reward: -687.9861324055722, Steps: 144, Time: 0.08s
# Episode 401: Total Reward: -66.62271593943754, Steps: 89, Time: 0.06s
# Checkpoint Reached!
# Episode 411: Total Reward: -250.8099783726362, Steps: 115, Time: 0.07s
# Episode 421: Total Reward: -275.34531001236553, Steps: 101, Time: 0.06s
# Episode 431: Total Reward: -690.4281057513897, Steps: 154, Time: 0.08s
# Episode 441: Total Reward: -162.49494807512923, Steps: 60, Time: 0.04s
# Episode 451: Total Reward: -111.39982843416205, Steps: 54, Time: 0.05s
# Episode 461: Total Reward: -131.61782100591392, Steps: 57, Time: 0.04s
# Episode 471: Total Reward: -243.53911279899958, Steps: 112, Time: 0.07s
# Episode 481: Total Reward: -102.56716569041588, Steps: 81, Time: 0.06s
# Episode 491: Total Reward: -41.118384377446226, Steps: 117, Time: 0.07s
# Episode 501: Total Reward: -432.81933456845906, Steps: 227, Time: 0.11s
# Checkpoint Reached!
# Episode 511: Total Reward: -358.1355680098971, Steps: 124, Time: 0.06s
# Episode 521: Total Reward: -232.06937568902762, Steps: 105, Time: 0.06s
# Episode 531: Total Reward: -332.32631743771014, Steps: 103, Time: 0.07s
# Episode 541: Total Reward: -75.30133296415264, Steps: 76, Time: 0.05s
# Episode 551: Total Reward: -109.45114661495654, Steps: 90, Time: 0.06s
# Episode 561: Total Reward: -164.1486306655615, Steps: 93, Time: 0.06s
# Episode 571: Total Reward: -289.6851854516873, Steps: 91, Time: 0.06s
# Episode 581: Total Reward: -113.32615098718287, Steps: 81, Time: 0.05s
# Episode 591: Total Reward: -205.95898106747367, Steps: 75, Time: 0.05s
# Episode 601: Total Reward: -175.90196323916663, Steps: 76, Time: 0.05s
# Checkpoint Reached!
# Episode 611: Total Reward: -152.39264069077024, Steps: 64, Time: 0.05s
# Episode 621: Total Reward: -168.09992354902732, Steps: 65, Time: 0.05s
# Episode 631: Total Reward: -138.72440534320378, Steps: 72, Time: 0.05s
# Episode 641: Total Reward: -213.59473731382406, Steps: 108, Time: 0.07s
# Episode 651: Total Reward: -90.85135396757704, Steps: 72, Time: 0.05s
# Episode 661: Total Reward: -47.05455002791858, Steps: 125, Time: 0.08s
# Episode 671: Total Reward: -390.00224606472005, Steps: 87, Time: 0.05s
# Episode 681: Total Reward: -105.07354252100419, Steps: 111, Time: 0.06s
# Episode 691: Total Reward: -242.28600054707846, Steps: 117, Time: 0.06s
# Episode 701: Total Reward: -209.20664645465715, Steps: 81, Time: 0.05s
# Checkpoint Reached!
# Episode 711: Total Reward: -171.0200483755061, Steps: 80, Time: 0.05s
# Episode 721: Total Reward: -107.70726395770441, Steps: 83, Time: 0.05s
# Episode 731: Total Reward: -113.82413249975862, Steps: 90, Time: 0.06s
# Episode 741: Total Reward: -26.656033933280753, Steps: 138, Time: 0.07s
# Episode 751: Total Reward: -99.03186510525569, Steps: 77, Time: 0.05s
# Episode 761: Total Reward: -122.82491235733283, Steps: 83, Time: 0.05s
# Episode 771: Total Reward: -42.530948346332515, Steps: 68, Time: 0.05s
# Episode 781: Total Reward: -56.01423385970932, Steps: 152, Time: 0.08s
# Episode 791: Total Reward: -42.83954393155147, Steps: 108, Time: 0.07s
# Episode 801: Total Reward: -473.1055157939486, Steps: 304, Time: 0.14s
# Checkpoint Reached!
# Episode 811: Total Reward: -84.59402953211456, Steps: 76, Time: 0.05s
# Episode 821: Total Reward: -105.07508626197536, Steps: 120, Time: 0.07s
# Episode 831: Total Reward: -139.2380285010851, Steps: 77, Time: 0.05s
# Episode 841: Total Reward: -90.77437856335463, Steps: 103, Time: 0.06s
# Episode 851: Total Reward: -45.82324116648387, Steps: 94, Time: 0.06s
# Episode 861: Total Reward: -49.74459701649975, Steps: 77, Time: 0.05s
# Episode 871: Total Reward: -108.58516047001736, Steps: 78, Time: 0.05s
# Episode 881: Total Reward: -101.45933942434702, Steps: 80, Time: 0.05s
# Episode 891: Total Reward: -161.72634858119162, Steps: 82, Time: 0.05s
# Episode 901: Total Reward: -81.53855217267285, Steps: 91, Time: 0.06s
# Checkpoint Reached!
# Episode 911: Total Reward: -72.98793419880784, Steps: 95, Time: 0.06s
# Episode 921: Total Reward: -44.88715689222103, Steps: 86, Time: 0.06s
# Episode 931: Total Reward: -7.279584165972409, Steps: 82, Time: 0.05s
# Episode 941: Total Reward: -256.9567214904089, Steps: 93, Time: 0.05s
# Episode 951: Total Reward: -77.83732059717114, Steps: 75, Time: 0.06s
# Episode 961: Total Reward: -94.69851287657964, Steps: 141, Time: 0.08s
# Episode 971: Total Reward: -178.92238755198676, Steps: 88, Time: 0.06s
# Episode 981: Total Reward: -137.75929844581782, Steps: 75, Time: 0.05s
# Episode 991: Total Reward: -432.9108872476136, Steps: 104, Time: 0.07s
# Episode 1001: Total Reward: -35.87776456816816, Steps: 111, Time: 0.06s
# Checkpoint Reached!
# Episode 1011: Total Reward: -378.13911150715217, Steps: 172, Time: 0.09s
# Episode 1021: Total Reward: -95.70362446771612, Steps: 100, Time: 0.07s
# Episode 1031: Total Reward: -78.90626395942512, Steps: 67, Time: 0.05s
# Episode 1041: Total Reward: -110.79288886815056, Steps: 75, Time: 0.05s
# Episode 1051: Total Reward: -170.13546811870336, Steps: 81, Time: 0.05s
# Episode 1061: Total Reward: -337.67187979979747, Steps: 116, Time: 0.07s
# Episode 1071: Total Reward: -175.5452355015893, Steps: 97, Time: 0.05s
# Episode 1081: Total Reward: 52.410498992979626, Steps: 90, Time: 0.06s
# Episode 1091: Total Reward: -276.17021610448927, Steps: 110, Time: 0.09s
# Episode 1101: Total Reward: -347.8150794896857, Steps: 105, Time: 0.06s
# Checkpoint Reached!
# Episode 1111: Total Reward: -228.82762807561673, Steps: 72, Time: 0.05s
# Episode 1121: Total Reward: -265.5194312743236, Steps: 137, Time: 0.08s
# Episode 1131: Total Reward: -244.0853913282537, Steps: 109, Time: 0.06s
# Episode 1141: Total Reward: -267.5210952358133, Steps: 141, Time: 0.08s
# Episode 1151: Total Reward: -240.45298157507733, Steps: 97, Time: 0.07s
# Episode 1161: Total Reward: -253.8511773801231, Steps: 113, Time: 0.08s
# Episode 1171: Total Reward: -218.5863078397412, Steps: 128, Time: 0.07s
# Episode 1181: Total Reward: -169.25426486448424, Steps: 104, Time: 0.07s
# Episode 1191: Total Reward: -322.6427286300152, Steps: 120, Time: 0.07s
# Episode 1201: Total Reward: -171.02072271470377, Steps: 100, Time: 0.06s
# Checkpoint Reached!
# Episode 1211: Total Reward: -221.16609784497288, Steps: 185, Time: 0.10s
# Episode 1221: Total Reward: -396.14835066749976, Steps: 117, Time: 0.06s
# Episode 1231: Total Reward: -185.50902391914457, Steps: 85, Time: 0.06s
# Episode 1241: Total Reward: -91.46861364692175, Steps: 99, Time: 0.07s
# Episode 1251: Total Reward: -396.5466409070047, Steps: 203, Time: 0.10s
# Episode 1261: Total Reward: -161.45605171940844, Steps: 63, Time: 0.04s
# Episode 1271: Total Reward: -210.38688394878494, Steps: 95, Time: 0.06s
# Episode 1281: Total Reward: -62.17528443021611, Steps: 83, Time: 0.06s
# Episode 1291: Total Reward: -110.16076153563093, Steps: 136, Time: 0.07s
# Episode 1301: Total Reward: -102.29985308574325, Steps: 128, Time: 0.07s
# Checkpoint Reached!
# Episode 1311: Total Reward: -107.93047915494057, Steps: 162, Time: 0.09s
# Episode 1321: Total Reward: -171.97885512670211, Steps: 75, Time: 0.05s
# Episode 1331: Total Reward: -13.033369471467267, Steps: 108, Time: 0.06s
# Episode 1341: Total Reward: -165.49596833979484, Steps: 96, Time: 0.06s
# Episode 1351: Total Reward: -186.34132532091365, Steps: 98, Time: 0.06s
# Episode 1361: Total Reward: -194.99346554600487, Steps: 98, Time: 0.06s
# Episode 1371: Total Reward: -234.6803268841822, Steps: 178, Time: 0.09s
# Episode 1381: Total Reward: -201.2487610153459, Steps: 85, Time: 0.05s
# Episode 1391: Total Reward: -226.31534287297822, Steps: 107, Time: 0.07s
# Episode 1401: Total Reward: -16.75071455885606, Steps: 87, Time: 0.07s
# Checkpoint Reached!
# Episode 1411: Total Reward: -188.96328383067254, Steps: 70, Time: 0.05s
# Episode 1421: Total Reward: -184.07080362491337, Steps: 112, Time: 0.07s
# Episode 1431: Total Reward: -91.2929518261152, Steps: 160, Time: 0.10s
# Episode 1441: Total Reward: -71.63769955049946, Steps: 65, Time: 0.06s
# Episode 1451: Total Reward: -103.57533878042821, Steps: 89, Time: 0.06s
# Episode 1461: Total Reward: -161.63672145422743, Steps: 102, Time: 0.06s
# Episode 1471: Total Reward: -161.93682539970501, Steps: 81, Time: 0.07s
# Episode 1481: Total Reward: -349.32747668908274, Steps: 87, Time: 0.05s
# Episode 1491: Total Reward: -255.3768516200032, Steps: 101, Time: 0.06s

# %% [markdown]
# ## Training Results

# %%
results = torch.load("ppo_lunar_lander_v3_checkpoint.pth", weights_only=False)

rewards_per_episode = results["rewards_per_episode"]
steps_per_episode = results["steps_per_episode"]

plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## LunarLander-v3 - Evaluation

# %%
steps_arr = []
rewards_arr = []

env_name = "LunarLander-v3"
lunar_env = gym.make(env_name)

state_dim = lunar_env.observation_space.shape[0]
action_dim = lunar_env.action_space.n

trained_agent = PPOAgent(state_dim, action_dim)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_agent.policy_net.load_state_dict(torch.load("ppo_lunar_lander_v3.pth", map_location=device, weights_only=True))

for episode in range(10):
    obs, _ = lunar_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action, _, _ = trained_agent.select_action(state)
        obs, reward, done, truncated, _ = lunar_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = 42.477541021160924, Steps taken: 1000
# Episode 2: Total Reward = -235.00946454230464, Steps taken: 106
# Episode 3: Total Reward = -474.5364438161627, Steps taken: 228
# Episode 4: Total Reward = -327.9099541747679, Steps taken: 118
# Episode 5: Total Reward = -297.4363402967888, Steps taken: 120
# Episode 6: Total Reward = -367.2085139042027, Steps taken: 148
# Episode 7: Total Reward = -185.4955849670958, Steps taken: 127
# Episode 8: Total Reward = -159.1413720191856, Steps taken: 120
# Episode 9: Total Reward = -191.648586955616, Steps taken: 92
# Episode 10: Total Reward = -373.7221822293384, Steps taken: 209
#
# Average reward over 10 episodes: -256.9630901884301
# Average steps taken over 10 episodes: 226.8
