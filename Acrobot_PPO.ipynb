# %% [markdown]
# # Acrobot - PPO

# %%
import os
import time
from abc import ABC, abstractmethod
from enum import Enum
from gymnasium import spaces
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque, namedtuple

from IPython.display import clear_output

# %pip install swig
# %pip install "gymnasium[box2d]"

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# Requirement already satisfied: swig in c:\users\viswa\anaconda3\lib\site-packages (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium[box2d] in c:\users\viswa\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\viswa\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Agent-related Class Definitions

# %%
class PPONet(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PPONet, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU()
        )
        self.actor = nn.Linear(128, action_dim)
        self.critic = nn.Linear(128, 1)

    def forward(self, x):
        x = self.shared(x)
        logits = self.actor(x)
        value = self.critic(x)
        return logits, value

class PPOAgent:
    BATCH_SIZE = 32
    CLIP_PARAM = 0.2
    GAMMA = 0.99
    LR = 1e-4
    GAE_LAMBDA = 0.95
    PPO_EPOCHS = 10
    VALUE_LOSS_COEF = 0.5
    ENTROPY_COEF = 0.01

    def __init__(self, state_dim, action_dim):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = PPONet(state_dim, action_dim).to(self.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.LR)
        self.memory = []
        self.clip = self.CLIP_PARAM

    def store_transition(self, state, action, reward, next_state, done, log_prob, value):
        self.memory.append((state, action, reward, next_state, done, log_prob, value))

    def select_action(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
        logits, value = self.policy_net(state_tensor)
        probs = F.softmax(logits, dim=-1)
        log_probs = F.log_softmax(logits, dim=-1)
        action = torch.multinomial(probs, 1).item()
        log_prob = log_probs[0, action].item()
        
        return action, log_prob, value.item()

    def compute_gae(self, rewards, values, next_value, dones):
        advantages = []
        gae = 0
        values = values + [next_value]
        for t in reversed(range(len(rewards))):
            delta = rewards[t] + self.GAMMA * values[t + 1] * (1 - dones[t]) - values[t]
            gae = delta + self.GAMMA * self.GAE_LAMBDA * (1 - dones[t]) * gae
            advantages.insert(0, gae)
        advantages = torch.tensor(advantages, dtype=torch.float32, device=self.device)
        returns = advantages + torch.tensor(values[:-1], dtype=torch.float32, device=self.device)
        
        return advantages, returns

    def step(self):
        if len(self.memory) < self.BATCH_SIZE:
            return

        states, actions, rewards, next_states, dones, old_log_probs, old_values = zip(*self.memory)
        states = torch.tensor(np.array(states), dtype=torch.float32, device=self.device)
        actions = torch.tensor(actions, dtype=torch.int64, device=self.device)
        old_log_probs = torch.tensor(old_log_probs, dtype=torch.float32, device=self.device)
        old_values = torch.tensor(old_values, dtype=torch.float32, device=self.device)

        with torch.no_grad():
            _, next_value = self.policy_net(states[-1:])
        advantages, returns = self.compute_gae(rewards, old_values.tolist(), next_value.item(), dones)
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.PPO_EPOCHS):
            logits, values = self.policy_net(states)
            probs = F.softmax(logits, dim=-1)
            log_probs = F.log_softmax(logits, dim=-1)
            selected_log_probs = log_probs[range(len(actions)), actions]

            ratios = torch.exp(selected_log_probs - old_log_probs)
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1 - self.clip, 1 + self.clip) * advantages
            policy_loss = -torch.min(surr1, surr2).mean()

            value_loss = F.mse_loss(values.squeeze(), returns)
            entropy = -(probs * log_probs).sum(dim=-1).mean()

            loss = policy_loss + self.VALUE_LOSS_COEF * value_loss - self.ENTROPY_COEF * entropy

            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        self.memory.clear()

# %% [markdown]
# ## Training Function Definition

# %%
def train_ppo(env, training_episodes=1000, agent_class=PPOAgent):
    CONVERGENCE_REWARD_COUNT = 20
    CONVERGENCE_MIN_REWARD = -70
    
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n
    
    agent = agent_class(state_dim, action_dim)
    rewards_per_episode = []
    steps_per_episode = []
    episode_times = []
    start_episode = 0
    early_stop_counter = 0

    for episode in range(training_episodes):
        start_time = time.time()
        obs, _ = env.reset()
        state = obs
        total_reward = 0
        done = False
        steps_taken = 0
        agent.memory = []
        episode_over = False

        while not episode_over:
            action, log_prob, value = agent.select_action(state)
            obs, reward, done, truncated, _ = env.step(action)
            next_state = np.array(obs, dtype=np.float32)
            total_reward += reward
            steps_taken += 1
            episode_over = done or truncated

            agent.store_transition(state, action, reward, next_state, done, log_prob, value)
            state = next_state

        average_rewards_over_last_episodes = np.mean(rewards_per_episode[-CONVERGENCE_REWARD_COUNT:])
          
        if average_rewards_over_last_episodes >= CONVERGENCE_MIN_REWARD and total_reward >= CONVERGENCE_MIN_REWARD:
            print("Early stopping condition met! Stopping training.")
            print(f"Episode {episode + 1:}: Total Reward: {total_reward:.3f}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
            break
        
        agent.step()
        steps_per_episode.append(steps_taken)
        rewards_per_episode.append(total_reward)
        episode_time = time.time() - start_time
        episode_times.append(episode_time)

        if episode % 10 == 0:    
            print(f"Episode {episode + 1}: Total Reward: {total_reward}, Steps: {steps_taken}, Time: {episode_time:.2f}s")
        if episode % 100 == 0:
            checkpoint = {
              'policy_net_state_dict': agent.policy_net.state_dict(),
              'optimizer_state_dict': agent.optimizer.state_dict(),
              'rewards_per_episode': rewards_per_episode,
              'episode_times': episode_times,
              'steps_per_episode': steps_per_episode
            }

            torch.save(checkpoint, "ppo_acrobot_v1_checkpoint.pth")
            torch.save(agent.policy_net.state_dict(), "ppo_acrobot_v1.pth")
            print("Checkpoint Reached!")
   
    return agent, rewards_per_episode, episode_times, steps_per_episode

# %% [markdown]
# ## Acrobot - Training

# %%
env_name = "Acrobot-v1"
acrobot_env = gym.make(env_name, max_episode_steps = 1000, render_mode="rgb_array")

trained_agent, rewards_per_episode, episode_times, steps_per_episode = train_ppo(acrobot_env, training_episodes = 1500)

checkpoint = {
    'policy_net_state_dict': trained_agent.policy_net.state_dict(),
    'optimizer_state_dict': trained_agent.optimizer.state_dict(),
    'rewards_per_episode': rewards_per_episode,
    'episode_times': episode_times,
    'steps_per_episode': steps_per_episode
}

torch.save(checkpoint, "ppo_acrobot_v1_checkpoint.pth")
torch.save(trained_agent.policy_net.state_dict(), "ppo_acrobot_v1.pth")
# Out:
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\viswa\anaconda3\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Episode 1: Total Reward: -818.0, Steps: 819, Time: 0.55s
# Checkpoint Reached!
# Episode 11: Total Reward: -1000.0, Steps: 1000, Time: 0.71s
# Episode 21: Total Reward: -597.0, Steps: 598, Time: 0.44s
# Episode 31: Total Reward: -474.0, Steps: 475, Time: 0.33s
# Episode 41: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Episode 51: Total Reward: -1000.0, Steps: 1000, Time: 0.62s
# Episode 61: Total Reward: -1000.0, Steps: 1000, Time: 0.61s
# Episode 71: Total Reward: -1000.0, Steps: 1000, Time: 0.66s
# Episode 81: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Episode 91: Total Reward: -1000.0, Steps: 1000, Time: 0.63s
# Episode 101: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Checkpoint Reached!
# Episode 111: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Episode 121: Total Reward: -1000.0, Steps: 1000, Time: 0.65s
# Episode 131: Total Reward: -1000.0, Steps: 1000, Time: 0.65s
# Episode 141: Total Reward: -1000.0, Steps: 1000, Time: 0.66s
# Episode 151: Total Reward: -1000.0, Steps: 1000, Time: 0.65s
# Episode 161: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Episode 171: Total Reward: -1000.0, Steps: 1000, Time: 0.64s
# Episode 181: Total Reward: -1000.0, Steps: 1000, Time: 0.62s
# Episode 191: Total Reward: -1000.0, Steps: 1000, Time: 0.61s
# Episode 201: Total Reward: -1000.0, Steps: 1000, Time: 0.62s
# Checkpoint Reached!
# Episode 211: Total Reward: -830.0, Steps: 831, Time: 0.60s
# Episode 221: Total Reward: -1000.0, Steps: 1000, Time: 0.69s
# Episode 231: Total Reward: -1000.0, Steps: 1000, Time: 0.69s
# Episode 241: Total Reward: -1000.0, Steps: 1000, Time: 0.67s
# Episode 251: Total Reward: -852.0, Steps: 853, Time: 0.58s
# Episode 261: Total Reward: -407.0, Steps: 408, Time: 0.31s
# Episode 271: Total Reward: -443.0, Steps: 444, Time: 0.31s
# Episode 281: Total Reward: -467.0, Steps: 468, Time: 0.31s
# Episode 291: Total Reward: -338.0, Steps: 339, Time: 0.24s
# Episode 301: Total Reward: -191.0, Steps: 192, Time: 0.14s
# Checkpoint Reached!
# Episode 311: Total Reward: -164.0, Steps: 165, Time: 0.13s
# Episode 321: Total Reward: -141.0, Steps: 142, Time: 0.12s
# Episode 331: Total Reward: -167.0, Steps: 168, Time: 0.13s
# Episode 341: Total Reward: -275.0, Steps: 276, Time: 0.23s
# Episode 351: Total Reward: -283.0, Steps: 284, Time: 0.24s
# Episode 361: Total Reward: -123.0, Steps: 124, Time: 0.11s
# Episode 371: Total Reward: -90.0, Steps: 91, Time: 0.09s
# Episode 381: Total Reward: -80.0, Steps: 81, Time: 0.08s
# Episode 391: Total Reward: -125.0, Steps: 126, Time: 0.15s
# Episode 401: Total Reward: -110.0, Steps: 111, Time: 0.10s
# Checkpoint Reached!
# Episode 411: Total Reward: -125.0, Steps: 126, Time: 0.13s
# Episode 421: Total Reward: -112.0, Steps: 113, Time: 0.13s
# Episode 431: Total Reward: -86.0, Steps: 87, Time: 0.09s
# Episode 441: Total Reward: -105.0, Steps: 106, Time: 0.12s
# Episode 451: Total Reward: -105.0, Steps: 106, Time: 0.10s
# Episode 461: Total Reward: -92.0, Steps: 93, Time: 0.09s
# Episode 471: Total Reward: -120.0, Steps: 121, Time: 0.11s
# Episode 481: Total Reward: -79.0, Steps: 80, Time: 0.09s
# Episode 491: Total Reward: -90.0, Steps: 91, Time: 0.09s
# Episode 501: Total Reward: -97.0, Steps: 98, Time: 0.10s
# Checkpoint Reached!
# Episode 511: Total Reward: -65.0, Steps: 66, Time: 0.07s
# Episode 521: Total Reward: -123.0, Steps: 124, Time: 0.11s
# Episode 531: Total Reward: -118.0, Steps: 119, Time: 0.12s
# Episode 541: Total Reward: -95.0, Steps: 96, Time: 0.09s
# Episode 551: Total Reward: -121.0, Steps: 122, Time: 0.11s
# Episode 561: Total Reward: -96.0, Steps: 97, Time: 0.09s
# Episode 571: Total Reward: -92.0, Steps: 93, Time: 0.10s
# Episode 581: Total Reward: -80.0, Steps: 81, Time: 0.10s
# Episode 591: Total Reward: -80.0, Steps: 81, Time: 0.09s
# Episode 601: Total Reward: -98.0, Steps: 99, Time: 0.10s
# Checkpoint Reached!
# Episode 611: Total Reward: -175.0, Steps: 176, Time: 0.30s
# Episode 621: Total Reward: -98.0, Steps: 99, Time: 0.11s
# Episode 631: Total Reward: -89.0, Steps: 90, Time: 0.11s
# Episode 641: Total Reward: -63.0, Steps: 64, Time: 0.08s
# Episode 651: Total Reward: -74.0, Steps: 75, Time: 0.09s
# Episode 661: Total Reward: -95.0, Steps: 96, Time: 0.10s
# Episode 671: Total Reward: -112.0, Steps: 113, Time: 0.12s
# Episode 681: Total Reward: -95.0, Steps: 96, Time: 0.09s
# Episode 691: Total Reward: -97.0, Steps: 98, Time: 0.11s
# Episode 701: Total Reward: -114.0, Steps: 115, Time: 0.12s
# Checkpoint Reached!
# Episode 711: Total Reward: -88.0, Steps: 89, Time: 0.09s
# Episode 721: Total Reward: -87.0, Steps: 88, Time: 0.09s
# Episode 731: Total Reward: -62.0, Steps: 63, Time: 0.07s
# Episode 741: Total Reward: -75.0, Steps: 76, Time: 0.09s
# Episode 751: Total Reward: -76.0, Steps: 77, Time: 0.08s
# Episode 761: Total Reward: -91.0, Steps: 92, Time: 0.09s
# Episode 771: Total Reward: -72.0, Steps: 73, Time: 0.09s
# Episode 781: Total Reward: -64.0, Steps: 65, Time: 0.10s
# Episode 791: Total Reward: -85.0, Steps: 86, Time: 0.11s
# Episode 801: Total Reward: -85.0, Steps: 86, Time: 0.11s
# Checkpoint Reached!
# Episode 811: Total Reward: -91.0, Steps: 92, Time: 0.09s
# Episode 821: Total Reward: -84.0, Steps: 85, Time: 0.09s
# Episode 831: Total Reward: -94.0, Steps: 95, Time: 0.10s
# Episode 841: Total Reward: -80.0, Steps: 81, Time: 0.09s
# Episode 851: Total Reward: -181.0, Steps: 182, Time: 0.14s
# Episode 861: Total Reward: -88.0, Steps: 89, Time: 0.09s
# Episode 871: Total Reward: -77.0, Steps: 78, Time: 0.09s
# Episode 881: Total Reward: -72.0, Steps: 73, Time: 0.09s
# Episode 891: Total Reward: -126.0, Steps: 127, Time: 0.12s
# Episode 901: Total Reward: -148.0, Steps: 149, Time: 0.13s
# Checkpoint Reached!
# Episode 911: Total Reward: -73.0, Steps: 74, Time: 0.09s
# Episode 921: Total Reward: -77.0, Steps: 78, Time: 0.08s
# Episode 931: Total Reward: -88.0, Steps: 89, Time: 0.08s
# Episode 941: Total Reward: -94.0, Steps: 95, Time: 0.10s
# Episode 951: Total Reward: -83.0, Steps: 84, Time: 0.10s
# Episode 961: Total Reward: -73.0, Steps: 74, Time: 0.09s
# Episode 971: Total Reward: -64.0, Steps: 65, Time: 0.07s
# Episode 981: Total Reward: -93.0, Steps: 94, Time: 0.09s
# Episode 991: Total Reward: -92.0, Steps: 93, Time: 0.09s
# Episode 1001: Total Reward: -95.0, Steps: 96, Time: 0.09s
# Checkpoint Reached!
# Episode 1011: Total Reward: -148.0, Steps: 149, Time: 0.12s
# Episode 1021: Total Reward: -71.0, Steps: 72, Time: 0.07s
# Episode 1031: Total Reward: -95.0, Steps: 96, Time: 0.09s
# Episode 1041: Total Reward: -90.0, Steps: 91, Time: 0.09s
# Episode 1051: Total Reward: -69.0, Steps: 70, Time: 0.08s
# Episode 1061: Total Reward: -73.0, Steps: 74, Time: 0.09s
# Episode 1071: Total Reward: -86.0, Steps: 87, Time: 0.12s
# Episode 1081: Total Reward: -111.0, Steps: 112, Time: 0.11s
# Episode 1091: Total Reward: -89.0, Steps: 90, Time: 0.10s
# Episode 1101: Total Reward: -99.0, Steps: 100, Time: 0.11s
# Checkpoint Reached!
# Episode 1111: Total Reward: -75.0, Steps: 76, Time: 0.09s
# Episode 1121: Total Reward: -173.0, Steps: 174, Time: 0.16s
# Episode 1131: Total Reward: -80.0, Steps: 81, Time: 0.10s
# Episode 1141: Total Reward: -79.0, Steps: 80, Time: 0.10s
# Episode 1151: Total Reward: -257.0, Steps: 258, Time: 0.21s
# Episode 1161: Total Reward: -90.0, Steps: 91, Time: 0.10s
# Episode 1171: Total Reward: -111.0, Steps: 112, Time: 0.10s
# Episode 1181: Total Reward: -102.0, Steps: 103, Time: 0.11s
# Episode 1191: Total Reward: -72.0, Steps: 73, Time: 0.08s
# Episode 1201: Total Reward: -95.0, Steps: 96, Time: 0.12s
# Checkpoint Reached!
# Episode 1211: Total Reward: -87.0, Steps: 88, Time: 0.11s
# Episode 1221: Total Reward: -95.0, Steps: 96, Time: 0.11s
# Episode 1231: Total Reward: -146.0, Steps: 147, Time: 0.15s
# Episode 1241: Total Reward: -81.0, Steps: 82, Time: 0.09s
# Episode 1251: Total Reward: -65.0, Steps: 66, Time: 0.10s
# Episode 1261: Total Reward: -74.0, Steps: 75, Time: 0.09s
# Episode 1271: Total Reward: -71.0, Steps: 72, Time: 0.09s
# Episode 1281: Total Reward: -89.0, Steps: 90, Time: 0.09s
# Episode 1291: Total Reward: -98.0, Steps: 99, Time: 0.11s
# Episode 1301: Total Reward: -83.0, Steps: 84, Time: 0.10s
# Checkpoint Reached!
# Episode 1311: Total Reward: -85.0, Steps: 86, Time: 0.08s
# Episode 1321: Total Reward: -113.0, Steps: 114, Time: 0.11s
# Episode 1331: Total Reward: -86.0, Steps: 87, Time: 0.10s
# Episode 1341: Total Reward: -92.0, Steps: 93, Time: 0.10s
# Episode 1351: Total Reward: -86.0, Steps: 87, Time: 0.09s
# Episode 1361: Total Reward: -88.0, Steps: 89, Time: 0.08s
# Episode 1371: Total Reward: -81.0, Steps: 82, Time: 0.08s
# Episode 1381: Total Reward: -96.0, Steps: 97, Time: 0.11s
# Episode 1391: Total Reward: -82.0, Steps: 83, Time: 0.09s
# Episode 1401: Total Reward: -79.0, Steps: 80, Time: 0.09s
# Checkpoint Reached!
# Episode 1411: Total Reward: -84.0, Steps: 85, Time: 0.08s
# Episode 1421: Total Reward: -132.0, Steps: 133, Time: 0.11s
# Episode 1431: Total Reward: -76.0, Steps: 77, Time: 0.07s
# Episode 1441: Total Reward: -85.0, Steps: 86, Time: 0.08s
# Episode 1451: Total Reward: -71.0, Steps: 72, Time: 0.07s
# Episode 1461: Total Reward: -94.0, Steps: 95, Time: 0.09s
# Episode 1471: Total Reward: -84.0, Steps: 85, Time: 0.08s
# Episode 1481: Total Reward: -88.0, Steps: 89, Time: 0.08s
# Episode 1491: Total Reward: -77.0, Steps: 78, Time: 0.11s

# %% [markdown]
# ## Training Results

# %%
results = torch.load("ppo_acrobot_v1_checkpoint.pth", weights_only=False)

rewards_per_episode = results["rewards_per_episode"]
steps_per_episode = results["steps_per_episode"]

plt.plot(rewards_per_episode)
plt.title("Rewards Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_per_episode)
plt.title("Steps Per Episode - Training")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()

# %% [markdown]
# ## Acrobot - Evaluation

# %%
steps_arr = []
rewards_arr = []

env_name = "Acrobot-v1"
acrobot_env = gym.make(env_name, render_mode="rgb_array")

state_dim = acrobot_env.observation_space.shape[0]
action_dim = acrobot_env.action_space.n

trained_agent = PPOAgent(state_dim, action_dim)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_agent.policy_net.load_state_dict(torch.load("ppo_acrobot_v1.pth", map_location=device, weights_only=True))

for episode in range(10):
    obs, _ = acrobot_env.reset()
    state = obs
    tot_reward = 0
    episode_over = False
    steps_taken = 0
    
    while not episode_over:
        with torch.no_grad():
            action, _, _ = trained_agent.select_action(state)
        obs, reward, done, truncated, _ = acrobot_env.step(action)
        episode_over = done or truncated
        state = np.array(obs, dtype=np.float32)
        steps_taken +=1
        tot_reward += reward
    rewards_arr.append(tot_reward)
    steps_arr.append(steps_taken)
    print(f"Episode {episode + 1}: Total Reward = {tot_reward}, Steps taken: {steps_taken}")

print(f"\nAverage reward over 10 episodes: {np.mean(rewards_arr)}")
print(f"Average steps taken over 10 episodes: {np.mean(steps_arr)}\n")

plt.plot(rewards_arr, marker="o")
plt.title("Rewards Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Rewards")

plt.show()

plt.plot(steps_arr, marker="o")
plt.title("Steps Per Episode - Evaluation")
plt.xlabel("Episode")
plt.ylabel("Steps Taken")

plt.show()
# Out:
# Episode 1: Total Reward = -97.0, Steps taken: 98
# Episode 2: Total Reward = -72.0, Steps taken: 73
# Episode 3: Total Reward = -137.0, Steps taken: 138
# Episode 4: Total Reward = -73.0, Steps taken: 74
# Episode 5: Total Reward = -72.0, Steps taken: 73
# Episode 6: Total Reward = -86.0, Steps taken: 87
# Episode 7: Total Reward = -138.0, Steps taken: 139
# Episode 8: Total Reward = -87.0, Steps taken: 88
# Episode 9: Total Reward = -83.0, Steps taken: 84
# Episode 10: Total Reward = -78.0, Steps taken: 79
#
# Average reward over 10 episodes: -92.3
# Average steps taken over 10 episodes: 93.3
